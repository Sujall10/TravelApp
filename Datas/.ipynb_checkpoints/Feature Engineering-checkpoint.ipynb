# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
df = pd.read_excel('Finaldatasett.xlsx')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40738 entries, 0 to 40737
# Data columns (total 31 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   User_Id              40738 non-null  int64
#  1   company              40738 non-null  object
#  2   Name                 40738 non-null  object
#  3   gender               40738 non-null  object
#  4   age                  40738 non-null  int64
#  5   travelCode           40738 non-null  int64
#  6   Departure            40738 non-null  object
#  7   Arrival              40738 non-null  object
#  8   flightType           40738 non-null  object
#  9   Flight_price         40738 non-null  float64
#  10  Flight_duration      40738 non-null  float64
#  11  Flight_Distance      40738 non-null  float64
#  12  Flight_agency        40738 non-null  object
#  13  Departure_date       40738 non-null  object
#  14  Hotel_Name           40738 non-null  object
# ...

# %%
guest = pd.read_csv('guest_profile.csv')
guest.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   guestID          10000 non-null  object
#  1   travelCode       10000 non-null  int64
#  2   code             10000 non-null  int64
#  3   name             10000 non-null  object
#  4   gender           10000 non-null  object
#  5   age              10000 non-null  int64
#  6   contactNumber    10000 non-null  object
#  7   email            10000 non-null  object
#  8   specialRequests  6587 non-null   object
#  9   roomPreference   10000 non-null  object
#  10  idProof          10000 non-null  object
# dtypes: int64(3), object(8)
# memory usage: 859.5+ KB

# %%
pax = pd.read_csv('pax_profile.csv')
pax.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 11 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   paxID           10000 non-null  object
#  1   travelCode      10000 non-null  object
#  2   code            10000 non-null  int64
#  3   name            10000 non-null  object
#  4   gender          10000 non-null  object
#  5   age             10000 non-null  int64
#  6   passportNumber  7005 non-null   object
#  7   nationality     10000 non-null  object
#  8   seatPreference  10000 non-null  object
#  9   mealPreference  10000 non-null  object
#  10  baggageDetails  10000 non-null  object
# dtypes: int64(2), object(9)
# memory usage: 859.5+ KB

# %%
merge_pax_n_guest = pd.merge(guest,pax,on="code", how='inner')
merge_pax_n_guest
# Out:
#                                     guestID  travelCode_x  code        name_x  \
# 0      5de419a5-94c5-4eb8-ab39-d0d361bda012         44376  1318  Eugene Hurst
# 1      5de419a5-94c5-4eb8-ab39-d0d361bda012         44376  1318  Eugene Hurst
# 2      5de419a5-94c5-4eb8-ab39-d0d361bda012         44376  1318  Eugene Hurst
# 3      5de419a5-94c5-4eb8-ab39-d0d361bda012         44376  1318  Eugene Hurst
# 4      5de419a5-94c5-4eb8-ab39-d0d361bda012         44376  1318  Eugene Hurst
# ...                                     ...           ...   ...           ...
# 73951  4b8a7537-132c-4765-bd1c-f7372df7340e         20654   383  James Gamble
# 73952  4b8a7537-132c-4765-bd1c-f7372df7340e         20654   383  James Gamble
# 73953  4b8a7537-132c-4765-bd1c-f7372df7340e         20654   383  James Gamble
# 73954  4b8a7537-132c-4765-bd1c-f7372df7340e         20654   383  James Gamble
# 73955  4b8a7537-132c-4765-bd1c-f7372df7340e         20654   383  James Gamble
#
# ...

# %%
merge_pax_n_guest.columns
# Out:
# Index(['guestID', 'travelCode_x', 'code', 'name_x', 'gender_x', 'age_x',
#        'contactNumber', 'email', 'specialRequests', 'roomPreference',
#        'idProof', 'paxID', 'travelCode_y', 'name_y', 'gender_y', 'age_y',
#        'passportNumber', 'nationality', 'seatPreference', 'mealPreference',
#        'baggageDetails'],
#       dtype='object')

# %%
merge_pax_n_guest.to_csv('Pax_Guest.csv')

# %%
merge_pax_n_guest.drop(['name_y','gender_y','age_y'], axis=1, inplace=True)

# %%
# merge_pax_n_guest.rename({'code':'User_ID'},axis=1,inplace=True)
# Merged_df = pd.merge(df,merge_pax_n_guest,on='travelCode', how='inner')
# Merged_df
# Merged_df.to_excel('Merged_all.xlsx',index=False)
# from IPython.display import FileLink
# FileLink('Merged_all.xlsx')

# %%
guest.rename({'code':'User_Id'}, axis=1,inplace=True)
# merge_only_pax = pd.merge(df,pax, on='User_ID', how='left' )
# merge_only_pax

# %%
# merge_only_pax = pd.merge(df,pax, on='User_Id', how='left' )
# merge_only_pax
merge_only_guest = pd.merge(df,guest, on='travelCode', how='left' )
merge_only_guest
# df['User_Id'].unique()
# Out:
#        User_Id_x        company            Name gender_x  age_x  travelCode  \
# 0              0           4You       Roy Braun     male     21           0
# 1              0           4You       Roy Braun     male     21           2
# 2              0           4You       Roy Braun     male     21           7
# 3              0           4You       Roy Braun     male     21          11
# 4              0           4You       Roy Braun     male     21          13
# ...          ...            ...             ...      ...    ...         ...
# 41840       1339  Umbrella LTDA  Paul Rodriguez     male     35      135938
# 41841       1339  Umbrella LTDA  Paul Rodriguez     male     35      135939
# 41842       1339  Umbrella LTDA  Paul Rodriguez     male     35      135940
# 41843       1339  Umbrella LTDA  Paul Rodriguez     male     35      135941
# 41844       1339  Umbrella LTDA  Paul Rodriguez     male     35      135942
#
# ...

# %%
# merge_only_guest.info()
merge_only_guest.drop(['specialRequests','roomPreference','guestID'],axis=1,inplace=True)
merge_only_guest
# Out:
#        User_Id_x        company            Name gender_x  age_x  travelCode  \
# 0              0           4You       Roy Braun     male     21           0
# 1              0           4You       Roy Braun     male     21           2
# 2              0           4You       Roy Braun     male     21           7
# 3              0           4You       Roy Braun     male     21          11
# 4              0           4You       Roy Braun     male     21          13
# ...          ...            ...             ...      ...    ...         ...
# 41840       1339  Umbrella LTDA  Paul Rodriguez     male     35      135938
# 41841       1339  Umbrella LTDA  Paul Rodriguez     male     35      135939
# 41842       1339  Umbrella LTDA  Paul Rodriguez     male     35      135940
# 41843       1339  Umbrella LTDA  Paul Rodriguez     male     35      135941
# 41844       1339  Umbrella LTDA  Paul Rodriguez     male     35      135942
#
# ...

# %%
merge_only_guest.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 41845 entries, 0 to 41844
# Data columns (total 38 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   User_Id_x            41845 non-null  int64
#  1   company              41845 non-null  object
#  2   Name                 41845 non-null  object
#  3   gender_x             41845 non-null  object
#  4   age_x                41845 non-null  int64
#  5   travelCode           41845 non-null  int64
#  6   Departure            41845 non-null  object
#  7   Arrival              41845 non-null  object
#  8   flightType           41845 non-null  object
#  9   Flight_price         41845 non-null  float64
#  10  Flight_duration      41845 non-null  float64
#  11  Flight_Distance      41845 non-null  float64
#  12  Flight_agency        41845 non-null  object
#  13  Departure_date       41845 non-null  object
#  14  Hotel_Name           41845 non-null  object
# ...

# %%
merge_only_guest.to_excel('Merged_all.xlsx',index=False)
from IPython.display import FileLink
FileLink('Merged_all.xlsx')
# Out:
# C:\Users\SURAJ\Desktop\Dataset\Merged_all.xlsx

# %%
merge_only_guest.rename(columns = {'User_Id':'User_ID'})
# Out:
#        User_Id_x        company            Name gender_x  age_x  travelCode  \
# 0              0           4You       Roy Braun     male     21           0
# 1              0           4You       Roy Braun     male     21           2
# 2              0           4You       Roy Braun     male     21           7
# 3              0           4You       Roy Braun     male     21          11
# 4              0           4You       Roy Braun     male     21          13
# ...          ...            ...             ...      ...    ...         ...
# 41840       1339  Umbrella LTDA  Paul Rodriguez     male     35      135938
# 41841       1339  Umbrella LTDA  Paul Rodriguez     male     35      135939
# 41842       1339  Umbrella LTDA  Paul Rodriguez     male     35      135940
# 41843       1339  Umbrella LTDA  Paul Rodriguez     male     35      135941
# 41844       1339  Umbrella LTDA  Paul Rodriguez     male     35      135942
#
# ...

# %%
merge_only_guest.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 41845 entries, 0 to 41844
# Data columns (total 38 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   User_Id_x            41845 non-null  int64
#  1   company              41845 non-null  object
#  2   Name                 41845 non-null  object
#  3   gender_x             41845 non-null  object
#  4   age_x                41845 non-null  int64
#  5   travelCode           41845 non-null  int64
#  6   Departure            41845 non-null  object
#  7   Arrival              41845 non-null  object
#  8   flightType           41845 non-null  object
#  9   Flight_price         41845 non-null  float64
#  10  Flight_duration      41845 non-null  float64
#  11  Flight_Distance      41845 non-null  float64
#  12  Flight_agency        41845 non-null  object
#  13  Departure_date       41845 non-null  object
#  14  Hotel_Name           41845 non-null  object
# ...

# %%
merge_only_guest.rename(columns={'User_Id_x':'User_ID'},inplace=True)

# %%
customer_call = pd.read_csv('supervisor_calls.csv')
customer_call.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 5 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   userID            200 non-null    int64
#  1   issueType         200 non-null    object
#  2   resolutionStatus  200 non-null    object
#  3   Date              200 non-null    object
#  4   supervisorID      200 non-null    int64
# dtypes: int64(2), object(3)
# memory usage: 7.9+ KB

# %%
customer_call.rename(columns = {'userID':'User_ID'},inplace=True)

# %%
customer_call.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 5 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   User_ID           200 non-null    int64
#  1   issueType         200 non-null    object
#  2   resolutionStatus  200 non-null    object
#  3   Date              200 non-null    object
#  4   supervisorID      200 non-null    int64
# dtypes: int64(2), object(3)
# memory usage: 7.9+ KB

# %%
merged = pd.merge(merge_only_guest, customer_call, on ="User_ID", how="left")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 merged = pd.merge(merge_only_guest, customer_call, on ="User_ID", how="left")
#
# NameError: name 'pd' is not defined

# %%
merged
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 merged
#
# NameError: name 'merged' is not defined

# %%
merged.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 42347 entries, 0 to 42346
# Data columns (total 42 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   User_ID              42347 non-null  int64
#  1   company              42347 non-null  object
#  2   Name                 42347 non-null  object
#  3   gender_x             42347 non-null  object
#  4   age_x                42347 non-null  int64
#  5   travelCode           42347 non-null  int64
#  6   Departure            42347 non-null  object
#  7   Arrival              42347 non-null  object
#  8   flightType           42347 non-null  object
#  9   Flight_price         42347 non-null  float64
#  10  Flight_duration      42347 non-null  float64
#  11  Flight_Distance      42347 non-null  float64
#  12  Flight_agency        42347 non-null  object
#  13  Departure_date       42347 non-null  object
#  14  Hotel_Name           42347 non-null  object
# ...

# %%
users = merged[['User_ID','company','Name','gender_x']]
users = users.drop_duplicates(subset =['User_ID'])

# %%
users
# Out:
#        User_ID        company              Name gender_x
# 0            0           4You         Roy Braun     male
# 27           1           4You    Joseph Holsten     male
# 29           2           4You     Wilma Mcinnis   female
# 66           3           4You      Paula Daniel   female
# 127          4           4You   Patricia Carson   female
# ...        ...            ...               ...      ...
# 42257     1335  Umbrella LTDA  Albert Garroutte     male
# 42321     1336  Umbrella LTDA        Kim Shores   female
# 42322     1337  Umbrella LTDA     James Gimenez     male
# 42333     1338  Umbrella LTDA      Viola Agosta   female
# 42334     1339  Umbrella LTDA    Paul Rodriguez     male
#
# [1310 rows x 4 columns]

# %%
Flights = merged[['travelCode','User_ID','Departure','Arrival','flightType','Flight_price','Flight_duration','Flight_Distance','Flight_agency','Departure_date']]
Flights
# Out:
#        travelCode  User_ID           Departure             Arrival  \
# 0               0        0         Recife (PE)  Florianopolis (SC)
# 1               2        0        Aracaju (SE)       Salvador (BH)
# 2               7        0        Aracaju (SE)       Salvador (BH)
# 3              11        0       Brasilia (DF)       Salvador (BH)
# 4              13        0         Recife (PE)  Florianopolis (SC)
# ...           ...      ...                 ...                 ...
# 42342      135938     1339  Florianopolis (SC)       Brasilia (DF)
# 42343      135939     1339  Florianopolis (SC)       Brasilia (DF)
# 42344      135940     1339  Florianopolis (SC)   Campo Grande (MS)
# 42345      135941     1339  Florianopolis (SC)   Campo Grande (MS)
# 42346      135942     1339  Florianopolis (SC)          Natal (RN)
#
#        flightType  Flight_price  Flight_duration  Flight_Distance  \
# 0      firstClass       1434.38             1.76           676.53
# ...

# %%
Flights['travelCode'].value_counts()
# Out:
# travelCode
# 26036     8
# 9505      6
# 95674     5
# 134615    4
# 34097     4
#          ..
# 45912     1
# 45918     1
# 45919     1
# 45923     1
# 135942    1
# Name: count, Length: 40552, dtype: int64

# %%
Flights = Flights.drop_duplicates(subset =['travelCode'])
Flights['travelCode'].value_counts()
# Out:
# travelCode
# 0         1
# 91032     1
# 91010     1
# 91012     1
# 91015     1
#          ..
# 44849     1
# 44852     1
# 44857     1
# 44866     1
# 135942    1
# Name: count, Length: 40552, dtype: int64

# %%
Flights['Departure_date'] = pd.to_datetime(Flights["Departure_date"], format='mixed', errors='coerce')
Flights['Departure_date'] = Flights['Departure_date'].dt.strftime("%d/%m/%Y")
Flights
# Out:
# C:\Users\SURAJ\AppData\Local\Temp\ipykernel_12776\1208417157.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Flights['Departure_date'] = pd.to_datetime(Flights["Departure_date"], format='mixed', errors='coerce')
# C:\Users\SURAJ\AppData\Local\Temp\ipykernel_12776\1208417157.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Flights['Departure_date'] = Flights['Departure_date'].dt.strftime("%d/%m/%Y")
#        travelCode  User_ID           Departure             Arrival  \
# ...

# %%
Hotel_booking = merged[['User_ID','travelCode','Hotel_Name','Arrival_place','Hotel_stay','Hotel_per_day_price','Check-in','Hotel_TotalPrice']]
Hotel_booking['Check-in'] = pd.to_datetime(Hotel_booking["Check-in"], format="%m/%d/%Y")
Hotel_booking['Check-in'] = Hotel_booking['Check-in'].dt.strftime("%d/%m/%Y")
Hotel_booking
# Out:
# C:\Users\SURAJ\AppData\Local\Temp\ipykernel_12776\817707263.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Hotel_booking['Check-in'] = pd.to_datetime(Hotel_booking["Check-in"], format="%m/%d/%Y")
# C:\Users\SURAJ\AppData\Local\Temp\ipykernel_12776\817707263.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Hotel_booking['Check-in'] = Hotel_booking['Check-in'].dt.strftime("%d/%m/%Y")
#        User_ID  travelCode Hotel_Name       Arrival_place  Hotel_stay  \
# ...

# %%
Hotel_booking['travelCode'].value_counts()
# Out:
# travelCode
# 26036     8
# 9505      6
# 95674     5
# 134615    4
# 34097     4
#          ..
# 45912     1
# 45918     1
# 45919     1
# 45923     1
# 135942    1
# Name: count, Length: 40552, dtype: int64

# %%
Hotel_booking = Hotel_booking.drop_duplicates(subset =['travelCode'])
Hotel_booking['travelCode'].value_counts()
# Out:
# travelCode
# 0         1
# 91032     1
# 91010     1
# 91012     1
# 91015     1
#          ..
# 44849     1
# 44852     1
# 44857     1
# 44866     1
# 135942    1
# Name: count, Length: 40552, dtype: int64

# %%
Hotel_booking
# Out:
#        User_ID  travelCode Hotel_Name       Arrival_place  Hotel_stay  \
# 0            0           0    Hotel A  Florianopolis (SC)           4
# 1            0           2    Hotel K       Salvador (BH)           2
# 2            0           7    Hotel K       Salvador (BH)           3
# 3            0          11    Hotel K       Salvador (BH)           4
# 4            0          13    Hotel A  Florianopolis (SC)           1
# ...        ...         ...        ...                 ...         ...
# 42342     1339      135938   Hotel BP       Brasilia (DF)           3
# 42343     1339      135939   Hotel BP       Brasilia (DF)           1
# 42344     1339      135940   Hotel BW   Campo Grande (MS)           3
# 42345     1339      135941   Hotel BW   Campo Grande (MS)           3
# 42346     1339      135942   Hotel BD          Natal (RN)           4
#
#        Hotel_per_day_price    Check-in  Hotel_TotalPrice
# 0                   313.02  26/09/2019           1252.08
# ...

# %%
merged.columns
# Out:
# Index(['User_ID', 'company', 'Name', 'gender_x', 'age_x', 'travelCode',
#        'Departure', 'Arrival', 'flightType', 'Flight_price', 'Flight_duration',
#        'Flight_Distance', 'Flight_agency', 'Departure_date', 'Hotel_Name',
#        'Arrival_place', 'Hotel_stay', 'Hotel_per_day_price',
#        'Hotel_TotalPrice', 'Check-in', 'pickupLocation', 'dropoffLocation',
#        'carType', 'rentalAgency', 'rentalDuration', 'Car_price',
#        'Car_total_distance', 'fuelPolicy', 'Car_bookingStatus',
#        'total_rent_price', 'total_trip_cost', 'User_Id_y', 'name', 'gender_y',
#        'age_y', 'contactNumber', 'email', 'idProof', 'issueType',
#        'resolutionStatus', 'Date', 'supervisorID'],
#       dtype='object')

# %%
car_rent = merged[['User_ID','travelCode','Check-in','pickupLocation','dropoffLocation','carType','rentalAgency','rentalDuration','Car_total_distance','fuelPolicy','Car_bookingStatus','total_rent_price']]
car_rent = car_rent.dropna(subset=['pickupLocation'])
car_rent
# Out:
#        User_ID  travelCode    Check-in    pickupLocation dropoffLocation  \
# 6            0          22  02/27/2020          Johntown      Port Brian
# 15           0          45  08/06/2020         Owensland        Ruizfort
# 37           2         117  02/27/2020        Edwardview       Katiefort
# 38           2         119  03/12/2020      Moranborough  Lake Stephanie
# 39           2         119  03/12/2020      Moranborough  Lake Stephanie
# ...        ...         ...         ...               ...             ...
# 42310     1335      135831  12/29/2022        West Donna       Fordshire
# 42313     1335      135843  03/23/2023  East Crystalview      Lake Laura
# 42332     1337      135892  04/16/2020         Kylehaven        Johnland
# 42335     1339      135911  12/12/2019       South Julie       Brentside
# 42344     1339      135940  07/02/2020     Port Paulfurt     Timothyview
#
#          carType rentalAgency  rentalDuration  Car_total_distance  \
# ...

# %%
car_rent  = car_rent.drop_duplicates(subset=['travelCode', 'User_ID'])
car_rent
# Out:
#        User_ID  travelCode    Check-in    pickupLocation  dropoffLocation  \
# 6            0          22  02/27/2020          Johntown       Port Brian
# 15           0          45  08/06/2020         Owensland         Ruizfort
# 37           2         117  02/27/2020        Edwardview        Katiefort
# 38           2         119  03/12/2020      Moranborough   Lake Stephanie
# 46           2         153  11/05/2020  Port Kathrynstad  East Ronnieberg
# ...        ...         ...         ...               ...              ...
# 42310     1335      135831  12/29/2022        West Donna        Fordshire
# 42313     1335      135843  03/23/2023  East Crystalview       Lake Laura
# 42332     1337      135892  04/16/2020         Kylehaven         Johnland
# 42335     1339      135911  12/12/2019       South Julie        Brentside
# 42344     1339      135940  07/02/2020     Port Paulfurt      Timothyview
#
#          carType rentalAgency  rentalDuration  Car_total_distance  \
# ...

# %%
Guest = merged[['User_Id_y','travelCode','name','gender_y','age_y','contactNumber','email','idProof']]
Guest = Guest.dropna(subset=['name'])
Guest.rename(columns={'User_Id_y':'Guest_ID','name':'Guest_name','gender_y':'Guest_Gender','age_y':'Age','contactNumber':'Guest_PhoneNo','email':'Guest_email'},inplace=True)
Guest
# Out:
#        Guest_ID  travelCode         Guest_name Guest_Gender   Age  \
# 8         993.0          32       Taylor Watts         Male  45.0
# 9        1138.0          33      Rebecca Reyes        Other  58.0
# 13        697.0          42      Matthew Terry       Female  22.0
# 18        367.0          54     Michael Romero       Female  50.0
# 30       1075.0         101    Dana Walker PhD       Female  64.0
# ...         ...         ...                ...          ...   ...
# 42334    1321.0      135903       Justin Adams       Female  19.0
# 42335     499.0      135911  Kevin Alvarez DDS         Male  43.0
# 42338     610.0      135925      Robert Little       Female  45.0
# 42343     750.0      135939         Alexis Cox        Other  18.0
# 42344    1152.0      135940         Paul Crane        Other  50.0
#
#                Guest_PhoneNo                   Guest_email  \
# 8                 5248880397        scottgomez@example.com
# ...

# %%
for a in Guest['travelCode'].unique():
    df = Guest[Guest['travelCode'] == a]
    duplicate_rows = df.duplicated(subset=['Guest_name'])
    duplicates = df[duplicate_rows]
duplicates
# Out:
# Empty DataFrame
# Columns: [Guest_ID, travelCode, Guest_name, Guest_Gender, Age, Guest_PhoneNo, Guest_email, idProof]
# Index: []

# %%
Guest['travelCode'].value_counts()
# Out:
# travelCode
# 26036     8
# 9505      6
# 95674     5
# 67293     4
# 113387    4
#          ..
# 48267     1
# 48200     1
# 48199     1
# 48163     1
# 135940    1
# Name: count, Length: 8902, dtype: int64

# %%
Customer_call = merged[['User_ID','Departure_date','issueType','resolutionStatus','Date','supervisorID']]
Customer_call.dropna(subset=['issueType'], inplace=True)
# Out:
# C:\Users\SURAJ\AppData\Local\Temp\ipykernel_12776\2780533053.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Customer_call.dropna(subset=['issueType'], inplace=True)

# %%
Customer_call.drop('Date',axis=1,inplace=True)
# Out:
# C:\Users\SURAJ\AppData\Local\Temp\ipykernel_12776\770961509.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Customer_call.drop('Date',axis=1,inplace=True)

# %%
Customer_call['Departure_date'] = pd.to_datetime(Customer_call["Departure_date"], format="mixed")
Customer_call['Departure_date'] = Customer_call['Departure_date'].dt.strftime("%d/%m/%Y")
Customer_call
# Out:
# C:\Users\SURAJ\AppData\Local\Temp\ipykernel_12776\2691065803.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Customer_call['Departure_date'] = pd.to_datetime(Customer_call["Departure_date"], format="mixed")
# C:\Users\SURAJ\AppData\Local\Temp\ipykernel_12776\2691065803.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Customer_call['Departure_date'] = Customer_call['Departure_date'].dt.strftime("%d/%m/%Y")
# ...

# %%
Customer_call['Departure_date'] = pd.to_datetime(Customer_call['Departure_date'], dayfirst=True)
Customer_call['days'] = Customer_call['Departure_date'] + pd.Timedelta(days=1)
# Customer_call
# Out:
# C:\Users\SURAJ\AppData\Local\Temp\ipykernel_12776\850071718.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Customer_call['Departure_date'] = pd.to_datetime(Customer_call['Departure_date'], dayfirst=True)
# C:\Users\SURAJ\AppData\Local\Temp\ipykernel_12776\850071718.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Customer_call['days'] = Customer_call['Departure_date'] + pd.Timedelta(days=1)

# %%
Customer_call['days'] = pd.to_datetime(Customer_call["days"], format="mixed")
Customer_call['days'] = Customer_call['days'].dt.strftime("%d/%m/%Y")
Customer_call
# Out:
# C:\Users\SURAJ\AppData\Local\Temp\ipykernel_12776\2577462074.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Customer_call['days'] = pd.to_datetime(Customer_call["days"], format="mixed")
# C:\Users\SURAJ\AppData\Local\Temp\ipykernel_12776\2577462074.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Customer_call['days'] = Customer_call['days'].dt.strftime("%d/%m/%Y")
#        User_ID Departure_date         issueType resolutionStatus  \
# ...

# %%
Customer_call.rename(columns={'Departure_date':'Arrival_date'},inplace=True)
# Out:
# C:\Users\SURAJ\AppData\Local\Temp\ipykernel_12776\2293736468.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Customer_call.rename(columns={'Departure_date':'Arrival_date'},inplace=True)

# %%
Customer_call['Arrival_date'] = pd.to_datetime(Customer_call["Arrival_date"], format="mixed")
Customer_call['Arrival_date'] = Customer_call['Arrival_date'].dt.strftime("%d/%m/%Y")
Customer_call
# Out:
# C:\Users\SURAJ\AppData\Local\Temp\ipykernel_12776\64798121.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Customer_call['Arrival_date'] = pd.to_datetime(Customer_call["Arrival_date"], format="mixed")
# C:\Users\SURAJ\AppData\Local\Temp\ipykernel_12776\64798121.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Customer_call['Arrival_date'] = Customer_call['Arrival_date'].dt.strftime("%d/%m/%Y")
#        User_ID Arrival_date         issueType resolutionStatus  supervisorID  \
# ...

# %%
Customer_call.rename(columns={'days':'Call_Date'},inplace=True)
# Out:
# C:\Users\SURAJ\AppData\Local\Temp\ipykernel_12776\1076784342.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Customer_call.rename(columns={'days':'Call_Date'},inplace=True)

# %%
Customer_call
# Out:
#        User_ID Arrival_date         issueType resolutionStatus  supervisorID  \
# 325         10   03/10/2019    Check-in Delay        Escalated        1256.0
# 326         10   14/11/2019    Check-in Delay        Escalated        1256.0
# 327         10   26/12/2019    Check-in Delay        Escalated        1256.0
# 328         10   20/02/2020    Check-in Delay        Escalated        1256.0
# 329         10   12/03/2020    Check-in Delay        Escalated        1256.0
# ...        ...          ...               ...              ...           ...
# 42136     1330   12/05/2022    Check-in Delay         Resolved        1325.0
# 42137     1330   14/07/2022    Check-in Delay         Resolved        1325.0
# 42138     1330   25/08/2022    Check-in Delay         Resolved        1325.0
# 42139     1330   13/10/2022    Check-in Delay         Resolved        1325.0
# 42321     1336   10/10/2019  Room Cleanliness         Resolved        1425.0
#
#         Call_Date
# 325    04/10/2019
# ...

# %%
# Customer_call.to_excel('CustomerCallFINALdataset.xlsx', index=False)
# Guest.to_excel('GuestFINALdataset.xlsx', index=False)
# car_rent.to_excel('CarFINALdataset.xlsx', index=False)
# Hotel_booking.to_excel('HotelFINALdataset.xlsx', index=False)
# Flights.to_excel('FlightFINALdataset.xlsx', index=False)
# users.to_excel('PassengerFINALdataset.xlsx', index=False)
# FileLink('CustomerCallFINALdataset.xlsx')
# FileLink('GuestFINALdataset.xlsx')
# FileLink('CarFINALdataset.xlsx')
# FileLink('HotelFINALdataset.xlsx')
# FileLink('FlightFINALdataset.xlsx')
# FileLink('PassengerFINALdataset.xlsx')

# %%
Flights
# Out:
#        travelCode  User_ID           Departure             Arrival  \
# 0               0        0         Recife (PE)  Florianopolis (SC)
# 1               2        0        Aracaju (SE)       Salvador (BH)
# 2               7        0        Aracaju (SE)       Salvador (BH)
# 3              11        0       Brasilia (DF)       Salvador (BH)
# 4              13        0         Recife (PE)  Florianopolis (SC)
# ...           ...      ...                 ...                 ...
# 42342      135938     1339  Florianopolis (SC)       Brasilia (DF)
# 42343      135939     1339  Florianopolis (SC)       Brasilia (DF)
# 42344      135940     1339  Florianopolis (SC)   Campo Grande (MS)
# 42345      135941     1339  Florianopolis (SC)   Campo Grande (MS)
# 42346      135942     1339  Florianopolis (SC)          Natal (RN)
#
#        flightType  Flight_price  Flight_duration  Flight_Distance  \
# 0      firstClass       1434.38             1.76           676.53
# ...

# %%
Review = Flights[['travelCode','User_ID']]
Review
# Out:
#        travelCode  User_ID
# 0               0        0
# 1               2        0
# 2               7        0
# 3              11        0
# 4              13        0
# ...           ...      ...
# 42342      135938     1339
# 42343      135939     1339
# 42344      135940     1339
# 42345      135941     1339
# 42346      135942     1339
#
# [40552 rows x 2 columns]

# %%
Review['Car_rented']=car_rent['Car_bookingStatus']
Review
# Out:
# C:\Users\SURAJ\AppData\Local\Temp\ipykernel_12776\3881523084.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Review['Car_rented']=car_rent['Car_bookingStatus']
#        travelCode  User_ID Car_rented
# 0               0        0        NaN
# 1               2        0        NaN
# 2               7        0        NaN
# 3              11        0        NaN
# 4              13        0        NaN
# ...           ...      ...        ...
# 42342      135938     1339        NaN
# 42343      135939     1339        NaN
# 42344      135940     1339    Pending
# 42345      135941     1339        NaN
# 42346      135942     1339        NaN
#
# [40552 rows x 3 columns]

# %%
Review['Car_rented'].fillna('Not Rented',inplace=True)
# Out:
# C:\Users\SURAJ\AppData\Local\Temp\ipykernel_12776\4029652718.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Review['Car_rented'].fillna('Not Rented',inplace=True)

# %%
Review['Car_rented'].value_counts()
# Out:
# Car_rented
# Not Rented    36779
# Pending        1265
# Confirmed      1261
# Cancelled      1247
# Name: count, dtype: int64

# %%
Review.loc[Review['Car_rented'] == 'Not Rented', 'review_car'] = "null"
# Out:
# C:\Users\SURAJ\AppData\Local\Temp\ipykernel_12776\1993664640.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Review.loc[Review['Car_rented'] == 'Not Rented', 'review_car'] = "null"

# %%
Review.drop('Car',axis=1,inplace=True)
# Out:
# C:\Users\SURAJ\AppData\Local\Temp\ipykernel_12776\3767284181.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Review.drop('Car',axis=1,inplace=True)

# %%
Review
# Out:
#        travelCode  User_ID  Car_rented review_car
# 0               0        0  Not Rented       null
# 1               2        0  Not Rented       null
# 2               7        0  Not Rented       null
# 3              11        0  Not Rented       null
# 4              13        0  Not Rented       null
# ...           ...      ...         ...        ...
# 42342      135938     1339  Not Rented       null
# 42343      135939     1339  Not Rented       null
# 42344      135940     1339     Pending        NaN
# 42345      135941     1339  Not Rented       null
# 42346      135942     1339  Not Rented       null
#
# [40552 rows x 4 columns]

# %%
Review['Car_rented'].value_counts()
# Out:
# Car_rented
# Not Rented    36779
# Pending        1265
# Confirmed      1261
# Cancelled      1247
# Name: count, dtype: int64

# %%
car_rental_reviews = [
        "Excellent service! The car was clean, and the pickup was smooth. Highly recommend!",
        "Rented a car for a weekend trip—fuel-efficient and comfortable ride!",
        "Customer support was super helpful when I needed to extend my rental!",
        "Smooth online booking process. Got my car within 10 minutes at the airport!",
        "Loved the selection of cars! Got a brand-new car for an amazing price!",
        "The rental car was spotless and smelled great. No issues at all.",
        "No hidden fees, just a simple and straightforward experience. Would rent again!",
        "Got an upgrade to a luxury car for free. Best rental experience ever!",
        "Driving through the mountains in the Jeep I rented was an absolute dream.",
        "Returning the car was just as easy as picking it up. Hassle-free process!",
        "The car was fine, nothing fancy, but it did the job for my trip.",
        "Pricing was reasonable, but the customer service could have been more responsive.",
        "Had to wait a little at the counter, but the car itself was good.",
        "The vehicle was okay, but I wish they had explained the insurance options better.",
        "Decent rental experience, though the deposit refund took a little longer than expected.",
        "Car had a few scratches, but it drove fine. They noted it before I left.",
        "Pickup process took longer than expected, but overall, a fair deal.",
        "It wasn’t the model I originally booked, but it worked out fine.",
        "Reasonable rates, but their fuel policy could be more transparent.",
        "Needed better signage at the rental location. Spent 15 minutes looking for it.",
        "Horrible experience! Hidden fees doubled the rental cost!",
        "Car broke down midway, and their roadside assistance took hours to arrive.",
        "They charged me for a scratch that was already there! Be careful!",
        "Customer service was rude and unhelpful. Never renting from them again.",
        "Waited over an hour at the airport rental counter. Totally unacceptable!",
        "They didn’t have the car I booked and gave me a smaller one instead.",
        "Returned the car full, but they still charged me for fuel! Scam!",
        "The A/C wasn’t working in 40°C heat. Absolute nightmare.",
        "They charged my card for an extra day when I returned it on time.",
        "The car smelled like smoke even though it was supposed to be non-smoking.",
        "They gave me a car with low tire pressure. Had to stop and refill myself!",
        "Way too expensive for the quality of service they provide.",
        "Booked an automatic, but they only had manuals left when I arrived.",
        "The car was dirty when I picked it up. Clearly not cleaned properly.",
        "They refused to refund my security deposit even though there was no damage!"
    ]

# %%
import random
Review["review_car"] = Review['review_car'].apply(lambda x: random.choice(car_rental_reviews) if pd.isna(x) else x)
Review
# Out:
# C:\Users\SURAJ\AppData\Local\Temp\ipykernel_12776\2212497928.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Review["review_car"] = Review['review_car'].apply(lambda x: random.choice(car_rental_reviews) if pd.isna(x) else x)
#        travelCode  User_ID  Car_rented  \
# 0               0        0  Not Rented
# 1               2        0  Not Rented
# 2               7        0  Not Rented
# 3              11        0  Not Rented
# 4              13        0  Not Rented
# ...           ...      ...         ...
# 42342      135938     1339  Not Rented
# 42343      135939     1339  Not Rented
# 42344      135940     1339     Pending
# 42345      135941     1339  Not Rented
# 42346      135942     1339  Not Rented
#
# ...

# %%
Review.drop('car_review',axis=1,inplace=True)
# Out:
# C:\Users\SURAJ\AppData\Local\Temp\ipykernel_12776\7034391.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Review.drop('car_review',axis=1,inplace=True)

# %%
Review
# Out:
#        travelCode  User_ID  Car_rented  \
# 0               0        0  Not Rented
# 1               2        0  Not Rented
# 2               7        0  Not Rented
# 3              11        0  Not Rented
# 4              13        0  Not Rented
# ...           ...      ...         ...
# 42342      135938     1339  Not Rented
# 42343      135939     1339  Not Rented
# 42344      135940     1339     Pending
# 42345      135941     1339  Not Rented
# 42346      135942     1339  Not Rented
#
#                                               review_car
# 0                                                   null
# 1                                                   null
# 2                                                   null
# 3                                                   null
# 4                                                   null
# ...                                                  ...
# 42342                                               null
# ...

# %%
hotel_reviews = [
    "The hotel was absolutely stunning! Clean rooms, excellent service, and a breathtaking view.",
    "The staff went above and beyond to make our stay memorable. Will definitely return!",
    "Spacious and luxurious rooms with top-notch amenities. Highly recommended!",
    "The check-in process was smooth, and the hotel offered a complimentary room upgrade!",
    "Fantastic breakfast buffet with a wide variety of delicious options!",
    "The rooftop pool was a highlight of our trip—such a relaxing experience!",
    "Loved the location—right in the heart of the city with easy access to attractions.",
    "Rooms were well-maintained, and housekeeping did a great job every day.",
    "The hotel’s spa was an absolute treat. Best massage I’ve ever had!",
    "Great value for money! Got a five-star experience at a reasonable price.",
    "The concierge was super helpful in arranging local tours and dinner reservations.",
    "Loved the little touches like welcome drinks and personalized notes in the room.",
    "Extremely comfortable beds—best sleep I’ve had in a long time!",
    "Fast and free Wi-Fi, perfect for both business and leisure travelers.",
    "The hotel had a beautiful garden and outdoor seating area, perfect for unwinding.",
    "Decent stay, but nothing extraordinary. The hotel met expectations.",
    "The room was fine, but it didn’t quite match the pictures on the website.",
    "The location was convenient, but the surroundings were a bit noisy.",
    "Service was okay, but I expected a bit more from a hotel of this rating.",
    "Check-in took longer than expected, but the staff was polite.",
    "The gym was small but had the basic equipment I needed for a workout.",
    "The hotel restaurant was average—good food but a bit overpriced.",
    "Air conditioning worked well, but it was a little noisy at night.",
    "Stayed for one night; everything was fine, but nothing really stood out.",
    "Breakfast selection was decent but could use more variety.",
    "The view from my room was blocked, which was disappointing but not a dealbreaker.",
    "The hotel was clean, but I felt like the decor was a little outdated.",
    "There were minor maintenance issues, but they were resolved quickly.",
    "The staff was helpful, but service could have been a bit faster.",
    "The amenities were decent, but the hotel lacked a cozy, welcoming vibe.",
    "Terrible experience! The room was not clean, and the service was very slow.",
    "The hotel overbooked, and we had to wait hours for an available room.",
    "The room smelled musty, and the bathroom had mold in the corners!",
    "Paper-thin walls—I could hear everything from the neighboring rooms.",
    "Booked a king-size bed, but they gave me two single beds pushed together!",
    "The worst hotel stay ever! The room was dirty, and the sheets had stains.",
    "Booked a non-smoking room, but it reeked of cigarette smoke!",
    "The bathroom drain was clogged, and water pooled up every time I showered.",
    "Staff was rude and unhelpful when I asked for extra towels.",
    "The air conditioning barely worked, and it was too hot to sleep comfortably.",
    "The Wi-Fi was so slow that I couldn’t even send an email!",
    "The hotel photos were misleading—nothing looked as good in real life.",
    "I found bugs in my bed! Absolutely disgusting and unacceptable.",
    "Elevator was out of service, and I had to carry my bags up six flights of stairs!",
    "Room service took over an hour, and the food was cold by the time it arrived."
]

# %%
Review["review_hotel"] = Review['travelCode'].apply(lambda x: random.choice(hotel_reviews))
Review
# Out:
# C:\Users\SURAJ\AppData\Local\Temp\ipykernel_12776\2628781095.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Review["review_hotel"] = Review['travelCode'].apply(lambda x: random.choice(hotel_reviews))
#        travelCode  User_ID  Car_rented  \
# 0               0        0  Not Rented
# 1               2        0  Not Rented
# 2               7        0  Not Rented
# 3              11        0  Not Rented
# 4              13        0  Not Rented
# ...           ...      ...         ...
# 42342      135938     1339  Not Rented
# 42343      135939     1339  Not Rented
# 42344      135940     1339     Pending
# 42345      135941     1339  Not Rented
# 42346      135942     1339  Not Rented
#
# ...

# %%
Review['review_car'].value_counts()
# Out:
# review_car
# null                                                                                       36779
# Had to wait a little at the counter, but the car itself was good.                            130
# They gave me a car with low tire pressure. Had to stop and refill myself!                    127
# Rented a car for a weekend trip—fuel-efficient and comfortable ride!                         122
# Waited over an hour at the airport rental counter. Totally unacceptable!                     120
# Loved the selection of cars! Got a brand-new car for an amazing price!                       120
# Returned the car full, but they still charged me for fuel! Scam!                             119
# The car smelled like smoke even though it was supposed to be non-smoking.                    119
# The car was fine, nothing fancy, but it did the job for my trip.                             118
# ...

# %%
flights_reviews = [
    "The flight was on time and the staff was very courteous. Excellent experience!",
    "Comfortable seats and good in-flight entertainment. Highly recommend this airline.",
    "Had a smooth flight with no delays, and the food was surprisingly good.",
    "The flight was delayed, but the crew kept us informed and made sure we were comfortable.",
    "Great service! The check-in process was smooth, and the flight was very relaxing.",
    "The plane was clean and well-maintained. The staff was friendly throughout the flight.",
    "Long flight, but the in-flight amenities made the journey more enjoyable.",
    "The crew was very professional, and the flight was very smooth. Would fly again.",
    "Very comfortable flight with ample legroom. The entertainment options were good too.",
    "The flight was a little bumpy, but overall, it was a pleasant experience.",
    "The cabin crew was very attentive and made sure all our needs were met.",
    "I had no issues with the flight. It was comfortable, and the staff was nice.",
    "Excellent in-flight experience with a wide selection of movies and shows.",
    "The flight was smooth, and the staff was extremely helpful and friendly.",
    "I was impressed with the punctuality and the level of service throughout the flight."
    "The food was awful, and the seats were uncomfortable. Not a great experience.",
    "The flight was delayed, and there were no updates, which was frustrating.",
    "The legroom was a bit tight, but everything else was great. I would fly again.",
    "The food was below average, and there were no special meal options available.",
    "The entertainment system was outdated, and the flight was not as comfortable as expected.",
    "The flight was delayed for hours, and there was no apology or compensation.",
    "I had to wait too long for boarding, and the staff was not helpful.",
    "My flight was canceled, and I had to rebook. Customer service was helpful, though.",
    "The check-in process was slow, and the staff seemed disorganized.",
    "The cabin was dirty, and the bathrooms were not properly maintained.",
    "There was no Wi-Fi on the flight, and the entertainment options were limited.",
    "The flight attendants were rude, and the flight was uncomfortable.",
    "The airline lost my luggage, and it took several days to get it back.",
    "The seats were cramped, and the flight was uncomfortable from start to finish.",
    "The flight was overcrowded, and I was unable to get enough rest."
    "The flight was fine, but nothing really stood out about the experience.",
    "The airline met my expectations, but it wasn’t a memorable experience.",
    "The service was okay, but I expected a bit more for the price.",
    "I had no complaints, but the flight didn’t offer anything exceptional.",
    "The flight was on time, and the crew was polite, but overall it was just okay.",
    "The cabin was comfortable, but the food could have been better.",
    "The flight was uneventful, but the overall experience was just average.",
    "The boarding process was a bit slow, but other than that, the flight was fine.",
    "The legroom was adequate, but the overall experience didn’t wow me.",
    "The entertainment was decent, but I didn’t find anything to really enjoy.",
    "I didn’t experience any issues, but it wasn’t a standout flight either.",
    "The crew was professional, but the flight felt standard and routine.",
    "The flight went smoothly, but I wasn’t overly impressed with the service.",
    "It was a standard flight. Nothing wrong, but nothing exceptional either.",
    "The flight was comfortable, but I didn’t find it memorable in any way."
]

# %%
Review["review_flights"] = Review['travelCode'].apply(lambda x: random.choice(flights_reviews))
Review
# Out:
# C:\Users\SURAJ\AppData\Local\Temp\ipykernel_12776\1052326060.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Review["review_flights"] = Review['travelCode'].apply(lambda x: random.choice(flights_reviews))
#        travelCode  User_ID  Car_rented  \
# 0               0        0  Not Rented
# 1               2        0  Not Rented
# 2               7        0  Not Rented
# 3              11        0  Not Rented
# 4              13        0  Not Rented
# ...           ...      ...         ...
# 42342      135938     1339  Not Rented
# 42343      135939     1339  Not Rented
# 42344      135940     1339     Pending
# 42345      135941     1339  Not Rented
# 42346      135942     1339  Not Rented
#
# ...

# %%
def assign_rating(text):
    if any(word in text.lower() for word in ["excellent", "great", "luxurious", "smooth"]):
        return 5
    elif any(word in text.lower() for word in ["okay", "average", "decent"]):
        return 3
    elif any(word in text.lower() for word in ["terrible", "worst", "horrible", "dirty", "broke down"]):
        return 1
    elif any(word in text.lower() for word in['null']):
        return 0
    else:
        return 2

# %%
Review["flight_rating"] = Review["review_flights"].apply(assign_rating)
Review["hotel_rating"] = Review["review_hotel"].apply(assign_rating)
Review["car_rating"] = Review["review_car"].apply(assign_rating)
# Out:
# C:\Users\SURAJ\AppData\Local\Temp\ipykernel_12776\2460051726.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Review["flight_rating"] = Review["review_flights"].apply(assign_rating)
# C:\Users\SURAJ\AppData\Local\Temp\ipykernel_12776\2460051726.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Review["hotel_rating"] = Review["review_hotel"].apply(assign_rating)
# C:\Users\SURAJ\AppData\Local\Temp\ipykernel_12776\2460051726.py:3: SettingWithCopyWarning:
# ...

# %%
Review
# Out:
#        travelCode  User_ID  Car_rented  \
# 0               0        0  Not Rented
# 1               2        0  Not Rented
# 2               7        0  Not Rented
# 3              11        0  Not Rented
# 4              13        0  Not Rented
# ...           ...      ...         ...
# 42342      135938     1339  Not Rented
# 42343      135939     1339  Not Rented
# 42344      135940     1339     Pending
# 42345      135941     1339  Not Rented
# 42346      135942     1339  Not Rented
#
#                                               review_car  \
# 0                                                   null
# 1                                                   null
# 2                                                   null
# 3                                                   null
# 4                                                   null
# ...                                                  ...
# 42342                                               null
# ...

# %%
def calculate_overall_rating(row):
    if row["car_rating"] == 0:
        return row[["flight_rating", "hotel_rating"]].mean()
    else:
        return row[["flight_rating", "hotel_rating", "car_rating"]].mean()

# %%
Review['overall_rating'] = Review.apply(calculate_overall_rating, axis=1)

# %%
Review
# Out:
#        travelCode  User_ID  Car_rented  \
# 0               0        0  Not Rented
# 1               2        0  Not Rented
# 2               7        0  Not Rented
# 3              11        0  Not Rented
# 4              13        0  Not Rented
# ...           ...      ...         ...
# 42342      135938     1339  Not Rented
# 42343      135939     1339  Not Rented
# 42344      135940     1339     Pending
# 42345      135941     1339  Not Rented
# 42346      135942     1339  Not Rented
#
#                                               review_car  \
# 0                                                   null
# 1                                                   null
# 2                                                   null
# 3                                                   null
# 4                                                   null
# ...                                                  ...
# 42342                                               null
# ...

# %%
Review['overall_rating'].value_counts()
# Out:
# overall_rating
# 2.000000    19286
# 3.500000     8301
# 2.500000     5952
# 3.000000     1703
# 1.500000     1636
# 4.000000     1468
# 5.000000      824
# 2.333333      577
# 1.666667      263
# 3.333333      233
# 2.666667      203
# 1.000000       54
# 1.333333       20
# 3.666667       20
# 4.333333       12
# Name: count, dtype: int64

# %%
Review.to_excel('ReviewFINALdataset.xlsx', index=False)
FileLink('ReviewFINALdataset.xlsx')
# Out:
# C:\Users\SURAJ\Desktop\Dataset\ReviewFINALdataset.xlsx

# %%
Review.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 40552 entries, 0 to 42346
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   travelCode      40552 non-null  int64
#  1   User_ID         40552 non-null  int64
#  2   Car_rented      40552 non-null  object
#  3   review_car      40552 non-null  object
#  4   review_hotel    40552 non-null  object
#  5   review_flights  40552 non-null  object
#  6   flight_rating   40552 non-null  int64
#  7   hotel_rating    40552 non-null  int64
#  8   car_rating      40552 non-null  int64
#  9   overall_rating  40552 non-null  float64
# dtypes: float64(1), int64(5), object(4)
# memory usage: 4.4+ MB
