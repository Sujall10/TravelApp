# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('sidd_final_dataset.csv')
df
# Out:
#        travelCode  userCode_x_x    name_x               place  days  \
# 0               0             0   Hotel A  Florianopolis (SC)     4
# 1               2             0   Hotel K       Salvador (BH)     2
# 2               7             0   Hotel K       Salvador (BH)     3
# 3              11             0   Hotel K       Salvador (BH)     4
# 4              13             0   Hotel A  Florianopolis (SC)     1
# ...           ...           ...       ...                 ...   ...
# 40547      135938          1339  Hotel BP       Brasilia (DF)     3
# 40548      135939          1339  Hotel BP       Brasilia (DF)     1
# 40549      135940          1339  Hotel BW   Campo Grande (MS)     3
# 40550      135941          1339  Hotel BW   Campo Grande (MS)     3
# 40551      135942          1339  Hotel BD          Natal (RN)     4
#
#        hotel_perday  hotel_total      date_x                from  \
# 0            313.02      1252.08  09/26/2019         Recife (PE)
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40552 entries, 0 to 40551
# Data columns (total 31 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   travelCode       40552 non-null  int64
#  1   userCode_x_x     40552 non-null  int64
#  2   name_x           40552 non-null  object
#  3   place            40552 non-null  object
#  4   days             40552 non-null  int64
#  5   hotel_perday     40552 non-null  float64
#  6   hotel_total      40552 non-null  float64
#  7   date_x           40552 non-null  object
#  8   from             40552 non-null  object
#  9   to               40552 non-null  object
#  10  flightType       40552 non-null  object
#  11  flight_cost      40552 non-null  float64
#  12  time             40552 non-null  float64
#  13  distance         40552 non-null  float64
#  14  agency           40552 non-null  object
#  15  company          40552 non-null  object
# ...

# %%
car_df = df[['userCode_x_x','travelCode','date_x','pickupLocation','dropoffLocation','carType','rentalAgency','rentalDuration','totalDistance','fuelPolicy','bookingStatus','Total_car_price']
]
car_df
# Out:
#        userCode_x_x  travelCode      date_x pickupLocation dropoffLocation  \
# 0                 0           0  09/26/2019            NaN             NaN
# 1                 0           2  10/10/2019            NaN             NaN
# 2                 0           7  11/14/2019            NaN             NaN
# 3                 0          11  12/12/2019            NaN             NaN
# 4                 0          13  12/26/2019            NaN             NaN
# ...             ...         ...         ...            ...             ...
# 40547          1339      135938  06/18/2020            NaN             NaN
# 40548          1339      135939  06/25/2020            NaN             NaN
# 40549          1339      135940  07/02/2020  Port Paulfurt     Timothyview
# 40550          1339      135941  07/09/2020            NaN             NaN
# 40551          1339      135942  07/16/2020            NaN             NaN
#
# ...

# %%
car_df = car_df.dropna()
car_df
# Out:
#        userCode_x_x  travelCode      date_x    pickupLocation  \
# 6                 0          22  02/27/2020          Johntown
# 15                0          45  08/06/2020         Owensland
# 37                2         117  02/27/2020        Edwardview
# 38                2         119  03/12/2020      Moranborough
# 45                2         153  11/05/2020  Port Kathrynstad
# ...             ...         ...         ...               ...
# 40516          1335      135831  12/29/2022        West Donna
# 40519          1335      135843  03/23/2023  East Crystalview
# 40537          1337      135892  04/16/2020         Kylehaven
# 40540          1339      135911  12/12/2019       South Julie
# 40549          1339      135940  07/02/2020     Port Paulfurt
#
#        dropoffLocation    carType rentalAgency  rentalDuration  totalDistance  \
# 6           Port Brian      Sedan         Sixt             3.0          285.0
# ...

# %%
df = pd.read_excel('CarFINALdataset.xlsx')
df
# Out:
#       User_ID  travelCode    Check-in    pickupLocation  dropoffLocation  \
# 0           0          22  02/27/2020          Johntown       Port Brian
# 1           0          45  08/06/2020         Owensland         Ruizfort
# 2           2         117  02/27/2020        Edwardview        Katiefort
# 3           2         119  03/12/2020      Moranborough   Lake Stephanie
# 4           2         153  11/05/2020  Port Kathrynstad  East Ronnieberg
# ...       ...         ...         ...               ...              ...
# 3768     1335      135831  12/29/2022        West Donna        Fordshire
# 3769     1335      135843  03/23/2023  East Crystalview       Lake Laura
# 3770     1337      135892  04/16/2020         Kylehaven         Johnland
# 3771     1339      135911  12/12/2019       South Julie        Brentside
# 3772     1339      135940  07/02/2020     Port Paulfurt      Timothyview
#
#         carType rentalAgency  rentalDuration  Car_total_distance  \
# ...

# %%
car_df.drop(columns={'Total_car_price'},inplace=True)
car_df
# Out:
# C:\Users\SURAJ\AppData\Local\Temp\ipykernel_8764\1929349922.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   car_df.drop(columns={'Total_car_price'},inplace=True)
#        userCode_x_x  travelCode      date_x    pickupLocation  \
# 6                 0          22  02/27/2020          Johntown
# 15                0          45  08/06/2020         Owensland
# 37                2         117  02/27/2020        Edwardview
# 38                2         119  03/12/2020      Moranborough
# 45                2         153  11/05/2020  Port Kathrynstad
# ...             ...         ...         ...               ...
# 40516          1335      135831  12/29/2022        West Donna
# 40519          1335      135843  03/23/2023  East Crystalview
# ...

# %%
car_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3773 entries, 6 to 40549
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   userCode_x_x     3773 non-null   int64
#  1   travelCode       3773 non-null   int64
#  2   date_x           3773 non-null   object
#  3   pickupLocation   3773 non-null   object
#  4   dropoffLocation  3773 non-null   object
#  5   carType          3773 non-null   object
#  6   rentalAgency     3773 non-null   object
#  7   rentalDuration   3773 non-null   float64
#  8   totalDistance    3773 non-null   float64
#  9   fuelPolicy       3773 non-null   object
#  10  bookingStatus    3773 non-null   object
# dtypes: float64(2), int64(2), object(7)
# memory usage: 353.7+ KB

# %%
car_df = car_df.rename(columns={
    'userCode_x_x': 'User_ID',
    'date_x': 'Check-in',
    'totalDistance': 'Car_total_distance',
    'bookingStatus': 'Car_bookingStatus'
})

# %%
car_df
# Out:
#        User_ID  travelCode    Check-in    pickupLocation  dropoffLocation  \
# 6            0          22  02/27/2020          Johntown       Port Brian
# 15           0          45  08/06/2020         Owensland         Ruizfort
# 37           2         117  02/27/2020        Edwardview        Katiefort
# 38           2         119  03/12/2020      Moranborough   Lake Stephanie
# 45           2         153  11/05/2020  Port Kathrynstad  East Ronnieberg
# ...        ...         ...         ...               ...              ...
# 40516     1335      135831  12/29/2022        West Donna        Fordshire
# 40519     1335      135843  03/23/2023  East Crystalview       Lake Laura
# 40537     1337      135892  04/16/2020         Kylehaven         Johnland
# 40540     1339      135911  12/12/2019       South Julie        Brentside
# 40549     1339      135940  07/02/2020     Port Paulfurt      Timothyview
#
#          carType rentalAgency  rentalDuration  Car_total_distance  \
# ...

# %%
car_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3773 entries, 6 to 40549
# Data columns (total 11 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   User_ID             3773 non-null   int64
#  1   travelCode          3773 non-null   int64
#  2   Check-in            3773 non-null   object
#  3   pickupLocation      3773 non-null   object
#  4   dropoffLocation     3773 non-null   object
#  5   carType             3773 non-null   object
#  6   rentalAgency        3773 non-null   object
#  7   rentalDuration      3773 non-null   float64
#  8   Car_total_distance  3773 non-null   float64
#  9   fuelPolicy          3773 non-null   object
#  10  Car_bookingStatus   3773 non-null   object
# dtypes: float64(2), int64(2), object(7)
# memory usage: 353.7+ KB

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3773 entries, 0 to 3772
# Data columns (total 12 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   User_ID             3773 non-null   int64
#  1   travelCode          3773 non-null   int64
#  2   Check-in            3773 non-null   object
#  3   pickupLocation      3773 non-null   object
#  4   dropoffLocation     3773 non-null   object
#  5   carType             3773 non-null   object
#  6   rentalAgency        3773 non-null   object
#  7   rentalDuration      3773 non-null   int64
#  8   Car_total_distance  3773 non-null   int64
#  9   fuelPolicy          3773 non-null   object
#  10  Car_bookingStatus   3773 non-null   object
#  11  total_rent_price    3773 non-null   int64
# dtypes: int64(5), object(7)
# memory usage: 353.8+ KB

# %%
car_df.to_excel('Test_car.xlsx',index=False)
from IPython.display import FileLink
FileLink('Test_car.xlsx')
# Out:
# C:\Users\SURAJ\Desktop\Dataset\Datas\Test_car.xlsx
