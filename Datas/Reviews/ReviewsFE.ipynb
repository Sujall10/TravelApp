# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('car_negative_reviews.csv')
df1 = pd.read_csv('car_neutral_reviews.csv')

# %%
df
# Out:
#                                  review_id  \
# 0     26878171-696b-495c-b48d-524802dbfffc
# 1     130425bc-f623-4ce6-8b6e-a65d7916a7b8
# 2     fb89f02e-85f7-4637-b8f8-7a1ea5477141
# 3     17ea56eb-68d9-49c8-af26-d51139aa60f2
# 4     1bb9f961-bd65-4179-b52a-2b5a90079ecd
# ...                                    ...
# 2995  b915c13c-bf4e-4bc2-a6bb-c8e046fd4a77
# 2996  3636b1c0-36b1-4ee8-b75f-f1416ceed188
# 2997  c5ba4cba-97e5-4356-8a85-236f3dec9544
# 2998  744fc32a-5717-4413-a731-bff70dbeb37f
# 2999  2d5d5615-832a-4d3d-9d36-6ccca7a8256c
#
#                                             review_text sentiment  \
# 0     Worst rental ever! The frustrating was pickup ...  negative
# 1     Had high hopes, but the awful was mileage limi...  negative
# 2     The rental experience was bad. The GPS availab...  negative
# 3     I can't believe how frustrating this rental wa...  negative
# 4     I can't believe how disappointing this rental ...  negative
# ...

# %%
df1
# Out:
#                                  review_id  \
# 0     6fb18abb-d699-4e2d-a931-8d2fe43adb23
# 1     e9097b9c-bea9-4911-a4b0-85755a55cbda
# 2     78865922-4101-423e-9166-44081d4bed17
# 3     2d9c6b69-d9e2-4629-bcff-677c31248020
# 4     6106c842-6707-400a-aa53-6e3424ac954d
# ...                                    ...
# 2995  0d8c3dae-7104-40cd-ad43-62b3d0945451
# 2996  be791a03-62c1-4b9f-9ec3-93b39ba7fd75
# 2997  d85d4fe4-8d51-4400-95b5-05ffb6452c7f
# 2998  6da1cde5-0152-4d65-9067-eac1744f720b
# 2999  23f59a45-c45c-4467-9016-67e6d2ce166a
#
#                                             review_text sentiment  \
# 0     An ordinary experience. The passable was insur...   neutral
# 1     Nothing too exciting. The okay was staff profe...   neutral
# 2     A decent experience. The passable was fuel pol...   neutral
# 3     The rental was average. The booking ease was o...   neutral
# 4     Nothing too exciting. The decent was roadside ...   neutral
# ...

# %%
df.drop('review_text', axis = 1, inplace= True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3000 entries, 0 to 2999
# Data columns (total 3 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   review_id      3000 non-null   object
#  1   sentiment      3000 non-null   object
#  2   review_text.1  2896 non-null   object
# dtypes: object(3)
# memory usage: 70.4+ KB

# %%
df.dropna(inplace=True)

# %%
df
# Out:
#                                  review_id sentiment  \
# 0     26878171-696b-495c-b48d-524802dbfffc  negative
# 1     130425bc-f623-4ce6-8b6e-a65d7916a7b8  negative
# 2     fb89f02e-85f7-4637-b8f8-7a1ea5477141  negative
# 3     17ea56eb-68d9-49c8-af26-d51139aa60f2  negative
# 4     1bb9f961-bd65-4179-b52a-2b5a90079ecd  negative
# ...                                    ...       ...
# 2891  174257fa-014e-4305-9a5d-33ed278841ab  negative
# 2892  71865a4e-566b-4f9d-ba61-098b0b8211ea  negative
# 2893  b3b5e4ad-4dd7-4845-a1d0-328e99786ea8  negative
# 2894  2e8f8606-54a3-4fe9-8a29-1b1c21bfa12f  negative
# 2895  7f98a517-a7db-480a-a3cb-5c850c2300f5  negative
#
#                                           review_text.1
# 0     Worst rental ever! The frustrating was pickup ...
# 1     Had high hopes, but the awful was mileage limi...
# 2     The rental experience was bad. The GPS availab...
# 3     I can't believe how frustrating this rental wa...
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2896 entries, 0 to 2895
# Data columns (total 3 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   review_id      2896 non-null   object
#  1   sentiment      2896 non-null   object
#  2   review_text.1  2896 non-null   object
# dtypes: object(3)
# memory usage: 90.5+ KB
