# %%
import pandas as pd

# %%
Round_chatgpt = pd.read_excel('Final_RoundTripp_Modified_Updated.xlsx')
Round_chatgpt
# Out:
#      travelCode  User_ID           Departure        Arrival Departure_Date  \
# 0           503        4            Itanagar          Surat     2021-03-25
# 1          1479       13           Bengaluru  Visakhapatnam     2020-09-07
# 2          1666       15          Chandigarh    Navi Mumbai     2019-11-28
# 3          2069       18                Kota  Visakhapatnam     2021-01-28
# 4          2383       21            Shillong            Diu     2021-06-17
# ..          ...      ...                 ...            ...            ...
# 283      105129     1041  Thiruvananthapuram       Guwahati     2022-07-14
# 284      105134     1041              Mysuru        Chennai     2020-11-19
# 285      130685     1286            Srinagar           Mopa     2020-07-23
# 286      130696     1286          Puducherry        Chennai     2021-04-15
# 287      130775     1286          Jamshedpur         Shimla     2020-06-25
#
#     Return_Date  flightType Flight_agency  Flight Distance (km)  \
# ...

# %%
# Round_chatgpt.drop(columns={'Departure_Date','Return_Date'})
Round_chatgpt.head(20)
# Out:
#     travelCode  User_ID    Departure        Arrival Departure_Date  \
# 0          503        4     Itanagar          Surat     2021-03-25
# 1         1479       13    Bengaluru  Visakhapatnam     2020-09-07
# 2         1666       15   Chandigarh    Navi Mumbai     2019-11-28
# 3         2069       18         Kota  Visakhapatnam     2021-01-28
# 4         2383       21     Shillong            Diu     2021-06-17
# 5         2691       23     Bilaspur        Dabolim     2020-12-11
# 6         3787       39         Kota           Mopa     2020-09-04
# 7         4108       41     Bilaspur          Hisar     2020-12-03
# 8         4381       44        Hisar         Khowai     2020-06-18
# 9         5206       52       Bhopal           Puri     2020-11-19
# 10        5372       54  Bhubaneswar           Puri     2020-02-13
# 11        5472       55   Puducherry      Delhi NCR     2020-02-20
# 12        5587       56        Hisar    Navi Mumbai     2019-12-19
# ...

# %%
import pandas as pd

# Load the dataset
import pandas as pd

# Load the dataset (ensuring Flight Duration is read as a string)
df = pd.read_excel('Final_RoundTripp_Modified_Updated.xlsx', dtype={'Flight Duration (hh:mm)': str})

# Convert date columns to datetime format
df['Modified_Departure_Date'] = pd.to_datetime(df['Modified_Departure_Date'])
df['Modified_Return_Date'] = pd.to_datetime(df['Modified_Return_Date'])

# Ensure 'Flight Duration (hh:mm)' is formatted correctly and append ':00' for seconds
df['Flight_Duration'] = a['Flight Duration (hh:mm)'].astype(str) + ':00'

# Convert 'Flight_Duration' to timedelta
df['Flight_Duration'] = pd.to_timedelta(df['Flight_Duration'])

# Compute new arrival dates
df['arrival_date'] = df['Modified_Departure_Date'] + df['Flight_Duration']
df['return_arrival_date'] = df['Modified_Return_Date'] + df['Flight_Duration']


# Display the updated DataFrame
df = df.drop(columns=['Flight Duration (hh:mm)'])

df.head(20)
# Out:
#     travelCode  User_ID    Departure        Arrival Departure_Date  \
# 0          503        4     Itanagar          Surat     2021-03-25
# 1         1479       13    Bengaluru  Visakhapatnam     2020-09-07
# 2         1666       15   Chandigarh    Navi Mumbai     2019-11-28
# 3         2069       18         Kota  Visakhapatnam     2021-01-28
# 4         2383       21     Shillong            Diu     2021-06-17
# 5         2691       23     Bilaspur        Dabolim     2020-12-11
# 6         3787       39         Kota           Mopa     2020-09-04
# 7         4108       41     Bilaspur          Hisar     2020-12-03
# 8         4381       44        Hisar         Khowai     2020-06-18
# 9         5206       52       Bhopal           Puri     2020-11-19
# 10        5372       54  Bhubaneswar           Puri     2020-02-13
# 11        5472       55   Puducherry      Delhi NCR     2020-02-20
# 12        5587       56        Hisar    Navi Mumbai     2019-12-19
# ...

# %%
a= pd.read_excel("Final_RoundTripp.xlsx")

# %%
a
# Out:
#      travelCode  User_ID           Departure        Arrival  \
# 0           503        4            Itanagar          Surat
# 1          1479       13           Bengaluru  Visakhapatnam
# 2          1666       15          Chandigarh    Navi Mumbai
# 3          2069       18                Kota  Visakhapatnam
# 4          2383       21            Shillong            Diu
# ..          ...      ...                 ...            ...
# 283      105129     1041  Thiruvananthapuram       Guwahati
# 284      105134     1041              Mysuru        Chennai
# 285      130685     1286            Srinagar           Mopa
# 286      130696     1286          Puducherry        Chennai
# 287      130775     1286          Jamshedpur         Shimla
#
#           Departure_Date Return_Date  flightType Flight_agency  \
# 0    2021-03-25 00:00:00  2021-04-02  firstClass     Air India
# 1    2020-09-07 00:00:00  2020-09-15    economic        IndiGo
# ...

# %%
df.to_excel('Sujall.xlsx', index=False)
from IPython.display import FileLink
FileLink('Sujall.xlsx')
# Out:
# C:\Users\SURAJ\Desktop\Dataset\notebooks\Sujall.xlsx

# %%
df = df.drop(columns={'Departure_Date','Return_Date','Departure Time','Arrival Time','Return Departure Time'})
df
# Out:
#      travelCode  User_ID           Departure        Arrival  flightType  \
# 0           503        4            Itanagar          Surat  firstClass
# 1          1479       13           Bengaluru  Visakhapatnam    economic
# 2          1666       15          Chandigarh    Navi Mumbai  firstClass
# 3          2069       18                Kota  Visakhapatnam     premium
# 4          2383       21            Shillong            Diu    economic
# ..          ...      ...                 ...            ...         ...
# 283      105129     1041  Thiruvananthapuram       Guwahati     premium
# 284      105134     1041              Mysuru        Chennai    economic
# 285      130685     1286            Srinagar           Mopa  firstClass
# 286      130696     1286          Puducherry        Chennai  firstClass
# 287      130775     1286          Jamshedpur         Shimla  firstClass
#
#     Flight_agency  Flight Distance (km)  Roundtrip_Cost  Return Arrival Time  \
# ...

# %%
df =df.rename(columns={'Modified_Departure_Date':'Departure_Date','Modified_Return_Date':'ReturnDeparture_Date','arrival_date':'Arrival_Date','return_arrival_date':'ReturnArrival_Date'})

# %%
df
# Out:
#      travelCode  User_ID           Departure        Arrival  flightType  \
# 0           503        4            Itanagar          Surat  firstClass
# 1          1479       13           Bengaluru  Visakhapatnam    economic
# 2          1666       15          Chandigarh    Navi Mumbai  firstClass
# 3          2069       18                Kota  Visakhapatnam     premium
# 4          2383       21            Shillong            Diu    economic
# ..          ...      ...                 ...            ...         ...
# 283      105129     1041  Thiruvananthapuram       Guwahati     premium
# 284      105134     1041              Mysuru        Chennai    economic
# 285      130685     1286            Srinagar           Mopa  firstClass
# 286      130696     1286          Puducherry        Chennai  firstClass
# 287      130775     1286          Jamshedpur         Shimla  firstClass
#
#     Flight_agency  Flight Distance (km)  Roundtrip_Cost  Return Arrival Time  \
# ...

# %%
df = df.drop(columns={'Return Arrival Time'})

# %%
reorder = ['travelCode','User_ID','Departure','Arrival','Departure_Date','Arrival_Date','ReturnDeparture_Date','ReturnArrival_Date','flightType','Flight_agency','Flight Distance (km)','Flight_Duration','Roundtrip_Cost']

# %%
df = df[reorder]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 288 entries, 0 to 287
# Data columns (total 13 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   travelCode            288 non-null    int64
#  1   User_ID               288 non-null    int64
#  2   Departure             288 non-null    object
#  3   Arrival               288 non-null    object
#  4   Departure_Date        288 non-null    datetime64[ns]
#  5   Arrival_Date          288 non-null    datetime64[ns]
#  6   ReturnDeparture_Date  288 non-null    datetime64[ns]
#  7   ReturnArrival_Date    288 non-null    datetime64[ns]
#  8   flightType            288 non-null    object
#  9   Flight_agency         288 non-null    object
#  10  Flight Distance (km)  288 non-null    float64
#  11  Flight_Duration       288 non-null    timedelta64[ns]
#  12  Roundtrip_Cost        288 non-null    float64
# ...

# %%
df
