# %%
import pandas as pd

# %%
df = pd.read_excel('April-May.xlsx')
df
# Out:
#        flight_type flight_agency      departure_date  \
# 0       firstClass         GoAir 2025-04-10 13:19:00
# 1       firstClass     Akasa Air 2025-04-10 19:36:00
# 2       firstClass        IndiGo 2025-04-18 09:05:00
# 3       firstClass      SpiceJet 2025-04-01 07:38:00
# 4       firstClass      SpiceJet 2025-04-25 08:22:00
# ...            ...           ...                 ...
# 271883  firstClass      SpiceJet 2025-04-12 23:24:00
# 271884    economic     Akasa Air 2025-04-23 06:19:00
# 271885    economic     Air India 2025-04-28 01:04:00
# 271886    economic      SpiceJet 2025-04-02 20:34:00
# 271887    economic     Akasa Air 2025-04-07 11:38:00
#
#                                                 departure  \
# 0       Lokpriya Gopinath Bordoloi International Airpo...
# 1                                Vijayawada Airport (VGA)
# 2                Biju Patnaik International Airport (BAI)
# 3                      Nashik International Airport (ISK)
# ...

# %%
df = df[df['arrival'] != "Chhatrapati Shivaji Maharaj International Airport (BOmm)"]

# %%
df
# Out:
#        flight_type flight_agency      departure_date  \
# 0       firstClass         GoAir 2025-04-10 13:19:00
# 1       firstClass     Akasa Air 2025-04-10 19:36:00
# 2       firstClass        IndiGo 2025-04-18 09:05:00
# 3       firstClass      SpiceJet 2025-04-01 07:38:00
# 4       firstClass      SpiceJet 2025-04-25 08:22:00
# ...            ...           ...                 ...
# 271883  firstClass      SpiceJet 2025-04-12 23:24:00
# 271884    economic     Akasa Air 2025-04-23 06:19:00
# 271885    economic     Air India 2025-04-28 01:04:00
# 271886    economic      SpiceJet 2025-04-02 20:34:00
# 271887    economic     Akasa Air 2025-04-07 11:38:00
#
#                                                 departure  \
# 0       Lokpriya Gopinath Bordoloi International Airpo...
# 1                                Vijayawada Airport (VGA)
# 2                Biju Patnaik International Airport (BAI)
# 3                      Nashik International Airport (ISK)
# ...

# %%
df = df[df['arrival'] != "Chhatrapati Shivaji Maharaj International Airport (BOmm)"]

# %%
df
# Out:
#        flight_type flight_agency      departure_date  \
# 0       firstClass         GoAir 2025-04-10 13:19:00
# 1       firstClass     Akasa Air 2025-04-10 19:36:00
# 2       firstClass        IndiGo 2025-04-18 09:05:00
# 3       firstClass      SpiceJet 2025-04-01 07:38:00
# 4       firstClass      SpiceJet 2025-04-25 08:22:00
# ...            ...           ...                 ...
# 271883  firstClass      SpiceJet 2025-04-12 23:24:00
# 271884    economic     Akasa Air 2025-04-23 06:19:00
# 271885    economic     Air India 2025-04-28 01:04:00
# 271886    economic      SpiceJet 2025-04-02 20:34:00
# 271887    economic     Akasa Air 2025-04-07 11:38:00
#
#                                                 departure  \
# 0       Lokpriya Gopinath Bordoloi International Airpo...
# 1                                Vijayawada Airport (VGA)
# 2                Biju Patnaik International Airport (BAI)
# 3                      Nashik International Airport (ISK)
# ...

# %%
x = df[df['arrival'] == "Chhatrapati Shivaji Maharaj International Airport (BOmm)"]

# %%
x
# Out:
# Empty DataFrame
# Columns: [flight_type, flight_agency, departure_date, departure, arrival, flight_number, flight_distance, flight_duration, flight_price, departure_time, Arrival_date, arrival_time]
# Index: []

# %%
df[(df['arrival'] == "Chhatrapati Shivaji Maharaj International Airport (BOmm)") & 
   (df['departure'] == "Chhatrapati Shivaji Maharaj International Airport (BOmm)")]
# Out:
# Empty DataFrame
# Columns: [flight_type, flight_agency, departure_date, departure, arrival, flight_number, flight_distance, flight_duration, flight_price, departure_time, Arrival_date, arrival_time]
# Index: []

# %%
df_loc = pd.read_excel("AirportCoordinates.xlsx")

# %%
df_loc
# Out:
#     LocationID                                               Name  \
# 0            1             Coimbatore International Airport (CJB)
# 1            2                          Birsa Munda Airport (IXR)
# 2            3                    Goa International Airport (GOI)
# 3            4  Sardar Vallabhbhai Patel International Airport...
# 4            5           Rajiv Gandhi International Airport (HYD)
# 5            6                             Agartala Airport (IXA)
# 6            7  Chhatrapati Shivaji Maharaj International Airp...
# 7            8                   Pune International Airport (PNQ)
# 8            9                           Vijayawada Airport (VGA)
# 9           10                              Gwalior Airport (GWL)
# 10          11             Kempegowda International Airport (BLR)
# 11          12  Lokpriya Gopinath Bordoloi International Airpo...
# 12          13                             Bilaspur Airport (PAB)
# ...

# %%
code_to_name = dict(zip(df_loc['Name'], df_loc['City']))
df['Departure_City'] = df['departure'].map(code_to_name)
df['Arrival_City'] = df['arrival'].map(code_to_name)
df
# Out:
#        flight_type flight_agency      departure_date  \
# 0       firstClass         GoAir 2025-04-10 13:19:00
# 1       firstClass     Akasa Air 2025-04-10 19:36:00
# 2       firstClass        IndiGo 2025-04-18 09:05:00
# 3       firstClass      SpiceJet 2025-04-01 07:38:00
# 4       firstClass      SpiceJet 2025-04-25 08:22:00
# ...            ...           ...                 ...
# 271883  firstClass      SpiceJet 2025-04-12 23:24:00
# 271884    economic     Akasa Air 2025-04-23 06:19:00
# 271885    economic     Air India 2025-04-28 01:04:00
# 271886    economic      SpiceJet 2025-04-02 20:34:00
# 271887    economic     Akasa Air 2025-04-07 11:38:00
#
#                                                 departure  \
# 0       Lokpriya Gopinath Bordoloi International Airpo...
# 1                                Vijayawada Airport (VGA)
# 2                Biju Patnaik International Airport (BAI)
# 3                      Nashik International Airport (ISK)
# ...

# %%
df.to_excel('April-May2025.xlsx', index=False)
from IPython.display import FileLink
FileLink('April-May2025.xlsx')
# Out:
# C:\Users\SURAJ\Desktop\Dataset\notebooks\April-May2025.xlsx
