# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_excel("FinalFlightCTO.xlsx")

# %%
mid = len(df)//2
df = df.iloc[mid:]

# %%
df_filtered = df[
    (df['Departure'] == "Coimbatore International Airport (CJB)")
]
df_filtered
# Out:
#        travelCode  User_ID                               Departure  \
# 0               0        0  Coimbatore International Airport (CJB)
# 83            290        3  Coimbatore International Airport (CJB)
# 148           517        4  Coimbatore International Airport (CJB)
# 321          1151       10  Coimbatore International Airport (CJB)
# 347          1227       11  Coimbatore International Airport (CJB)
# ...           ...      ...                                     ...
# 39747      135101     1330  Coimbatore International Airport (CJB)
# 39786      135241     1331  Coimbatore International Airport (CJB)
# 39858      135523     1332  Coimbatore International Airport (CJB)
# 39864      135544     1333  Coimbatore International Airport (CJB)
# 39869      135564     1333  Coimbatore International Airport (CJB)
#
#                                                  Arrival      Departure_date  \
# 0                            Visakhapatnam Airport (VTZ) 2019-09-26 03:59:00
# ...

# %%
start_date = pd.Timestamp("2025-03-01")
end_date = pd.Timestamp("2025-05-15")

# %%
df["Departure_date"] = df["Departure_date"].apply(lambda _: start_date + pd.to_timedelta(np.random.randint(0, (end_date - start_date).days), unit='D'))

# %%
df = df.drop(columns={'Arrival_Date'})

# %%
df_filtered = df[
    (df['Departure_date'] == pd.to_datetime('2025-04-29')) &
    (df['Departure'] == "Coimbatore International Airport (CJB)")
]
df_filtered['Arrival'] = "Visakhapatnam Airport (VTZ)"
df_filtered
# Out:
# C:\Users\SURAJ\AppData\Local\Temp\ipykernel_17276\2532492139.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_filtered['Arrival'] = "Visakhapatnam Airport (VTZ)"
#        travelCode  User_ID                               Departure  \
# 0               0        0  Coimbatore International Airport (CJB)
# 7988        26772      258  Coimbatore International Airport (CJB)
# 12276       41362      401  Coimbatore International Airport (CJB)
# 14101       47487      461  Coimbatore International Airport (CJB)
# 14348       48391      474  Coimbatore International Airport (CJB)
# 14458       48785      478  Coimbatore International Airport (CJB)
# 14833       50037      488  Coimbatore International Airport (CJB)
# ...

# %%
df["Departure_date"] = pd.to_datetime(df["Departure_date"])
df["Departure_timee"] = pd.to_timedelta(df["Departure_time"] + ":00")
df["EstimatedDuration_HHmm"] = pd.to_timedelta(df["EstimatedDuration_HHMM"] + ":00") 
df["Arrival_Date"] = df["Departure_date"] + df["Departure_timee"] + df["EstimatedDuration_HHmm"]
df["Departure_date"] = df["Departure_date"] + df["Departure_timee"]

# %%
df = df.drop(columns={'Departure_timee','EstimatedDuration_HHmm'})

# %%
df["Departure_date"] = df["Departure_date"].dt.strftime('%Y-%m-%d')
df["Arrival_Date"] = df["Arrival_Date"].dt.strftime('%Y-%m-%d')

# %%
df
# Out:
#        travelCode  User_ID                                          Departure  \
# 0               0        0             Coimbatore International Airport (CJB)
# 1               2        0                          Birsa Munda Airport (IXR)
# 2               7        0                    Goa International Airport (GOI)
# 3              11        0  Sardar Vallabhbhai Patel International Airport...
# 4              13        0           Rajiv Gandhi International Airport (HYD)
# ...           ...      ...                                                ...
# 39974      135938     1339               Devi Ahilya Bai Holkar Airport (IDR)
# 39975      135939     1339  Sardar Vallabhbhai Patel International Airport...
# 39976      135940     1339                            Prayagraj Airport (IXD)
# 39977      135941     1339                                Surat Airport (STV)
# 39978      135942     1339                            Raja Bhoj Airport (BHO)
#
# ...

# %%
df.to_excel('FlightForFrontend.xlsx', index=False)
from IPython.display import FileLink
FileLink('FlightForFrontend.xlsx')
# Out:
# C:\Users\SURAJ\Desktop\Dataset\notebooks\FlightForFrontend.xlsx

# %%
df_filtered = df_filtered.drop(columns={'Distance_km','EstimatedDuration_HHMM','Arrival_time'})

# %%
d = {'Distance_km': 998.106548, 'EstimatedDuration_HHMM': pd.to_timedelta("01:13:00")}

# %%
df_filtered['Flight_Distance'] = 998.106548

# %%
df_filtered['EstimatedDuration_HHMM'] = pd.to_timedelta("01:13:00")

# %%
df_filtered
# Out:
#        travelCode  User_ID                               Departure  \
# 0               0        0  Coimbatore International Airport (CJB)
# 7988        26772      258  Coimbatore International Airport (CJB)
# 12276       41362      401  Coimbatore International Airport (CJB)
# 14101       47487      461  Coimbatore International Airport (CJB)
# 14348       48391      474  Coimbatore International Airport (CJB)
# 14458       48785      478  Coimbatore International Airport (CJB)
# 14833       50037      488  Coimbatore International Airport (CJB)
# 15202       51353      500  Coimbatore International Airport (CJB)
# 17157       58027      565  Coimbatore International Airport (CJB)
#
#                            Arrival Departure_date Departure_time  \
# 0      Visakhapatnam Airport (VTZ)     2025-04-29          03:59
# 7988   Visakhapatnam Airport (VTZ)     2025-04-29          16:13
# 12276  Visakhapatnam Airport (VTZ)     2025-04-29          12:07
# ...

# %%
df_filtered["Departure_date"] = pd.to_datetime(df_filtered["Departure_date"])
df_filtered["Departure_timee"] = pd.to_timedelta(df_filtered["Departure_time"] + ":00")
# df_filtered["EstimatedDuration_HHmm"] = pd.to_timedelta(df_filtered["EstimatedDuration_HHMM"] + ":00") 
# df_filtered["Arrival_Date"] = df_filtered["Departure_date"] + df_filtered["Departure_timee"] + df_filtered["EstimatedDuration_HHMM"]

# %%
df_filtered
# Out:
#        travelCode  User_ID                               Departure  \
# 0               0        0  Coimbatore International Airport (CJB)
# 7988        26772      258  Coimbatore International Airport (CJB)
# 12276       41362      401  Coimbatore International Airport (CJB)
# 14101       47487      461  Coimbatore International Airport (CJB)
# 14348       48391      474  Coimbatore International Airport (CJB)
# 14458       48785      478  Coimbatore International Airport (CJB)
# 14833       50037      488  Coimbatore International Airport (CJB)
# 15202       51353      500  Coimbatore International Airport (CJB)
# 17157       58027      565  Coimbatore International Airport (CJB)
#
#                            Arrival Departure_date Departure_time  \
# 0      Visakhapatnam Airport (VTZ)     2025-04-29          03:59
# 7988   Visakhapatnam Airport (VTZ)     2025-04-29          16:13
# 12276  Visakhapatnam Airport (VTZ)     2025-04-29          12:07
# ...

# %%
df_filtered["Arrival_Date"] = df_filtered["Arrival_Date"].dt.strftime('%Y-%m-%d')

# %%
df_filtered = df_filtered.drop(columns={'Departure_timee'})

# %%
df
# Out:
#        travelCode  User_ID                                          Departure  \
# 0               0        0             Coimbatore International Airport (CJB)
# 1               2        0                          Birsa Munda Airport (IXR)
# 2               7        0                    Goa International Airport (GOI)
# 3              11        0  Sardar Vallabhbhai Patel International Airport...
# 4              13        0           Rajiv Gandhi International Airport (HYD)
# ...           ...      ...                                                ...
# 39974      135938     1339               Devi Ahilya Bai Holkar Airport (IDR)
# 39975      135939     1339  Sardar Vallabhbhai Patel International Airport...
# 39976      135940     1339                            Prayagraj Airport (IXD)
# 39977      135941     1339                                Surat Airport (STV)
# 39978      135942     1339                            Raja Bhoj Airport (BHO)
#
# ...

# %%
df_filtered
# Out:
#        travelCode  User_ID                               Departure  \
# 0               0        0  Coimbatore International Airport (CJB)
# 7988        26772      258  Coimbatore International Airport (CJB)
# 12276       41362      401  Coimbatore International Airport (CJB)
# 14101       47487      461  Coimbatore International Airport (CJB)
# 14348       48391      474  Coimbatore International Airport (CJB)
# 14458       48785      478  Coimbatore International Airport (CJB)
# 14833       50037      488  Coimbatore International Airport (CJB)
# 15202       51353      500  Coimbatore International Airport (CJB)
# 17157       58027      565  Coimbatore International Airport (CJB)
#
#                            Arrival Departure_date Departure_time  \
# 0      Visakhapatnam Airport (VTZ)     2025-04-29          03:59
# 7988   Visakhapatnam Airport (VTZ)     2025-04-29          16:13
# 12276  Visakhapatnam Airport (VTZ)     2025-04-29          12:07
# ...

# %%
df_filtered['Arrival_time'] = df_filtered["Departure_timee"] + df_filtered["EstimatedDuration_HHMM"]
df_filtered
# Out:
#        travelCode  User_ID                               Departure  \
# 0               0        0  Coimbatore International Airport (CJB)
# 7988        26772      258  Coimbatore International Airport (CJB)
# 12276       41362      401  Coimbatore International Airport (CJB)
# 14101       47487      461  Coimbatore International Airport (CJB)
# 14348       48391      474  Coimbatore International Airport (CJB)
# 14458       48785      478  Coimbatore International Airport (CJB)
# 14833       50037      488  Coimbatore International Airport (CJB)
# 15202       51353      500  Coimbatore International Airport (CJB)
# 17157       58027      565  Coimbatore International Airport (CJB)
#
#                            Arrival Departure_date Departure_time  \
# 0      Visakhapatnam Airport (VTZ)     2025-04-29          03:59
# 7988   Visakhapatnam Airport (VTZ)     2025-04-29          16:13
# 12276  Visakhapatnam Airport (VTZ)     2025-04-29          12:07
# ...

# %%
df_filtered['Arrival_time'] = pd.to_timedelta(df_filtered['Arrival_time'])

# Convert timedelta to HH:MM format
df_filtered['Arrival_time'] = df_filtered['Arrival_time'].dt.components.apply(
    lambda x: f"{x.hours:02}:{x.minutes:02}", axis=1
)

# %%
df_filtered
# Out:
#        travelCode  User_ID                               Departure  \
# 0               0        0  Coimbatore International Airport (CJB)
# 7988        26772      258  Coimbatore International Airport (CJB)
# 12276       41362      401  Coimbatore International Airport (CJB)
# 14101       47487      461  Coimbatore International Airport (CJB)
# 14348       48391      474  Coimbatore International Airport (CJB)
# 14458       48785      478  Coimbatore International Airport (CJB)
# 14833       50037      488  Coimbatore International Airport (CJB)
# 15202       51353      500  Coimbatore International Airport (CJB)
# 17157       58027      565  Coimbatore International Airport (CJB)
#
#                            Arrival Departure_date Departure_time  \
# 0      Visakhapatnam Airport (VTZ)     2025-04-29          03:59
# 7988   Visakhapatnam Airport (VTZ)     2025-04-29          16:13
# 12276  Visakhapatnam Airport (VTZ)     2025-04-29          12:07
# ...

# %%
df = df.rename(columns={'Distance_km':'Flight_Distance'})

# %%
df
# Out:
#        travelCode  User_ID                                          Departure  \
# 19989       67875      658           Rajiv Gandhi International Airport (HYD)
# 19990       67876      658           Rajiv Gandhi International Airport (HYD)
# 19991       67879      658  Chhatrapati Shivaji Maharaj International Airp...
# 19992       67880      658                   Pune International Airport (PNQ)
# 19993       67885      658  Lokpriya Gopinath Bordoloi International Airpo...
# ...           ...      ...                                                ...
# 39974      135938     1339               Devi Ahilya Bai Holkar Airport (IDR)
# 39975      135939     1339  Sardar Vallabhbhai Patel International Airport...
# 39976      135940     1339                            Prayagraj Airport (IXD)
# 39977      135941     1339                                Surat Airport (STV)
# 39978      135942     1339                            Raja Bhoj Airport (BHO)
#
# ...

# %%
df0 = pd.concat([df_filtered, df], ignore_index=True)

# %%
df_filtered.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 9 entries, 0 to 17157
# Data columns (total 14 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   travelCode               9 non-null      int64
#  1   User_ID                  9 non-null      int64
#  2   Departure                9 non-null      object
#  3   Arrival                  9 non-null      object
#  4   Departure_date           9 non-null      object
#  5   Departure_time           9 non-null      object
#  6   flight_number            9 non-null      object
#  7   flightType               9 non-null      object
#  8   Flight_agency            9 non-null      object
#  9   Calculated_Flight_Price  9 non-null      float64
#  10  Flight_Distance          9 non-null      float64
#  11  EstimatedDuration_HHMM   9 non-null      object
#  12  Arrival_Date             9 non-null      object
#  13  Arrival_time             9 non-null      object
# ...

# %%
df0.to_excel('Frontendd.xlsx', index=False)
from IPython.display import FileLink
FileLink('Frontendd.xlsx')
# Out:
# C:\Users\SURAJ\Desktop\Dataset\notebooks\Frontendd.xlsx

# %%
df['Departure_date'] = df['Departure_date'].dt.strftime('%Y-%m-%d')
df['Arrival_Date'] = df['Arrival_Date'].dt.strftime('%Y-%m-%d')

# %%
df__
# Out:
#        travelCode  User_ID                                          Departure  \
# 0               0        0             Coimbatore International Airport (CJB)
# 1           26772      258             Coimbatore International Airport (CJB)
# 2           41362      401             Coimbatore International Airport (CJB)
# 3           47487      461             Coimbatore International Airport (CJB)
# 4           48391      474             Coimbatore International Airport (CJB)
# ...           ...      ...                                                ...
# 19994      135938     1339               Devi Ahilya Bai Holkar Airport (IDR)
# 19995      135939     1339  Sardar Vallabhbhai Patel International Airport...
# 19996      135940     1339                            Prayagraj Airport (IXD)
# 19997      135941     1339                                Surat Airport (STV)
# 19998      135942     1339                            Raja Bhoj Airport (BHO)
#
# ...

# %%
df['EstimatedDuration_HHMM'] = df['EstimatedDuration_HHMM'].dt.components.apply(
    lambda x: f"{x.hours:02}:{x.minutes:02}", axis=1
)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19990 entries, 19989 to 39978
# Data columns (total 14 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   travelCode               19990 non-null  int64
#  1   User_ID                  19990 non-null  int64
#  2   Departure                19990 non-null  object
#  3   Arrival                  19990 non-null  object
#  4   Departure_date           19990 non-null  object
#  5   Departure_time           19990 non-null  object
#  6   Arrival_Date             19990 non-null  object
#  7   Arrival_time             19990 non-null  object
#  8   flight_number            19990 non-null  object
#  9   flightType               19990 non-null  object
#  10  Flight_agency            19990 non-null  object
#  11  Flight_Distance          19990 non-null  float64
#  12  EstimatedDuration_HHMM   19990 non-null  object
#  13  Calculated_Flight_Price  19990 non-null  float64
# ...

# %%
df
# Out:
#        travelCode  User_ID                                          Departure  \
# 19989       67875      658           Rajiv Gandhi International Airport (HYD)
# 19990       67876      658           Rajiv Gandhi International Airport (HYD)
# 19991       67879      658  Chhatrapati Shivaji Maharaj International Airp...
# 19992       67880      658                   Pune International Airport (PNQ)
# 19993       67885      658  Lokpriya Gopinath Bordoloi International Airpo...
# ...           ...      ...                                                ...
# 39974      135938     1339               Devi Ahilya Bai Holkar Airport (IDR)
# 39975      135939     1339  Sardar Vallabhbhai Patel International Airport...
# 39976      135940     1339                            Prayagraj Airport (IXD)
# 39977      135941     1339                                Surat Airport (STV)
# 39978      135942     1339                            Raja Bhoj Airport (BHO)
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19990 entries, 19989 to 39978
# Data columns (total 14 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   travelCode               19990 non-null  int64
#  1   User_ID                  19990 non-null  int64
#  2   Departure                19990 non-null  object
#  3   Arrival                  19990 non-null  object
#  4   Departure_date           19990 non-null  object
#  5   Departure_time           19990 non-null  object
#  6   Arrival_Date             19990 non-null  object
#  7   Arrival_time             19990 non-null  object
#  8   flight_number            19990 non-null  object
#  9   flightType               19990 non-null  object
#  10  Flight_agency            19990 non-null  object
#  11  Distance_km              19990 non-null  float64
#  12  EstimatedDuration_HHMM   19990 non-null  object
#  13  Calculated_Flight_Price  19990 non-null  float64
# ...

# %%
df__.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19999 entries, 0 to 19998
# Data columns (total 15 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   travelCode               19999 non-null  int64
#  1   User_ID                  19999 non-null  int64
#  2   Departure                19999 non-null  object
#  3   Arrival                  19999 non-null  object
#  4   Departure_date           19999 non-null  object
#  5   Departure_time           19999 non-null  object
#  6   flight_number            19999 non-null  object
#  7   flightType               19999 non-null  object
#  8   Flight_agency            19999 non-null  object
#  9   Calculated_Flight_Price  19999 non-null  float64
#  10  Flight_Distance          9 non-null      float64
#  11  EstimatedDuration_HHMM   19999 non-null  object
#  12  Arrival_Date             19999 non-null  object
#  13  Arrival_time             19999 non-null  object
# ...

# %%
df = df.rename(columns={'Distance_km':'Flight_Distance'})

# %%
df0.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19999 entries, 0 to 19998
# Data columns (total 14 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   travelCode               19999 non-null  int64
#  1   User_ID                  19999 non-null  int64
#  2   Departure                19999 non-null  object
#  3   Arrival                  19999 non-null  object
#  4   Departure_date           19999 non-null  object
#  5   Departure_time           19999 non-null  object
#  6   flight_number            19999 non-null  object
#  7   flightType               19999 non-null  object
#  8   Flight_agency            19999 non-null  object
#  9   Calculated_Flight_Price  19999 non-null  float64
#  10  Flight_Distance          19999 non-null  float64
#  11  EstimatedDuration_HHMM   19999 non-null  object
#  12  Arrival_Date             19999 non-null  object
#  13  Arrival_time             19999 non-null  object
# ...
