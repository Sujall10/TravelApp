# %%
import pandas as pd

# %%
round_2 = pd.read_excel("roundtrip_modified_dataset_with_cost.xlsx")
round_2
# Out:
#      travelCode  User_ID  flightType Flight_agency Departure_date  \
# 0           503        4  firstClass     Air India     2021-03-25
# 1           590        4    economic      SpiceJet     2021-04-02
# 2          1479       13    economic        IndiGo     2020-09-07
# 3          1507       13    economic      SpiceJet     2020-09-15
# 4          1666       15  firstClass     Air India     2019-11-28
# ..          ...      ...         ...           ...            ...
# 383      133540     1315    economic     Akasa Air     2021-06-17
# 384      134586     1323     premium     Air India     2021-12-16
# 385      134613     1323  firstClass     Akasa Air     2021-12-30
# 386      135670     1335  firstClass        IndiGo     2019-11-28
# 387      135799     1335     premium     Akasa Air     2019-12-06
#
#          Departure        Arrival  Flight Distance (km)  \
# 0         Itanagar          Surat               2204.62
# 1            Surat       Itanagar               2204.62
# ...

# %%
round_2 = round_2.iloc[::2]
round_2
# Out:
#      travelCode  User_ID  flightType Flight_agency Departure_date   Departure  \
# 0           503        4  firstClass     Air India     2021-03-25    Itanagar
# 2          1479       13    economic        IndiGo     2020-09-07   Bengaluru
# 4          1666       15  firstClass     Air India     2019-11-28  Chandigarh
# 6          2069       18     premium     Akasa Air     2021-01-28        Kota
# 8          2383       21    economic        IndiGo     2021-06-17    Shillong
# ..          ...      ...         ...           ...            ...         ...
# 378      132731     1307  firstClass      SpiceJet     2020-05-21      Ranchi
# 380      133011     1311    economic     Air India     2020-07-30     Gwalior
# 382      133492     1315    economic     Akasa Air     2021-06-05      Shimla
# 384      134586     1323     premium     Air India     2021-12-16   Hyderabad
# 386      135670     1335  firstClass        IndiGo     2019-11-28     Raigarh
#
# ...

# %%
round_4 = pd.read_excel('roundtrip_detailed_costs.xlsx')
round_4
# Out:
#     User_ID                From            To Departure_Date Return_Date  \
# 0        34              Khowai       Ayodhya     2020-05-07  2020-07-12
# 1        34              Bhopal        Mysuru     2021-04-15  2021-05-22
# 2        63  Thiruvananthapuram    Vijayawada     2019-07-23  2019-11-07
# 3        63              Nashik    Coimbatore     2020-02-13  2020-03-18
# 4       132            Dehradun     Bengaluru     2019-10-10  2019-10-20
# ..      ...                 ...           ...            ...         ...
# 65     1080            Amritsar          Kota     2020-03-05  2020-05-23
# 66     1104           Delhi NCR      Guwahati     2020-04-30  2020-05-07
# 67     1104          Jamshedpur      Amritsar     2020-12-24  2021-01-02
# 68     1165         Bhubaneswar  Kullu-Manali     2019-10-31  2019-11-03
# 69     1165              Indore          Kota     2020-12-31  2021-01-02
#
#     Roundtrip_Cost
# 0         10211.83
# 1         12723.14
# 2          9833.92
# ...

# %%
round_4 = round_4.rename(columns={'From':'Departure','To':'Arrival'})

# %%
rounddd_4 = pd.read_excel("roundtrip_dataset_user_4.xlsx")
rounddd_4
# Out:
#      travelCode  User_ID  flightType Flight_agency Departure_date  \
# 0          3392       34  firstClass         GoAir     2020-05-07
# 1          3442       34     premium     Air India     2020-07-12
# 2          3441       34     premium     Air India     2021-04-15
# 3          3498       34  firstClass     Air India     2021-05-22
# 4          6422       63    economic     Akasa Air     2019-07-23
# ..          ...      ...         ...           ...            ...
# 135      111482     1104  firstClass         GoAir     2021-01-02
# 136      117586     1165    economic     Akasa Air     2019-10-31
# 137      117598     1165    economic        IndiGo     2019-11-03
# 138      117647     1165  firstClass     Air India     2020-12-31
# 139      117742     1165  firstClass         GoAir     2021-01-02
#
#         Departure             Arrival  Flight Distance (km)  \
# 0         Ayodhya              Khowai                991.41
# ...

# %%
rounddd_4 = rounddd_4.drop(columns={'Total Flight Cost'})

# %%
rounddd_4
# Out:
#      travelCode  User_ID  flightType Flight_agency Departure_date  \
# 0          3392       34  firstClass         GoAir     2020-05-07
# 1          3442       34     premium     Air India     2020-07-12
# 2          3441       34     premium     Air India     2021-04-15
# 3          3498       34  firstClass     Air India     2021-05-22
# 4          6422       63    economic     Akasa Air     2019-07-23
# ..          ...      ...         ...           ...            ...
# 135      111482     1104  firstClass         GoAir     2021-01-02
# 136      117586     1165    economic     Akasa Air     2019-10-31
# 137      117598     1165    economic        IndiGo     2019-11-03
# 138      117647     1165  firstClass     Air India     2020-12-31
# 139      117742     1165  firstClass         GoAir     2021-01-02
#
#         Departure             Arrival  Flight Distance (km)  \
# 0         Ayodhya              Khowai                991.41
# ...

# %%
round__4 = pd.merge(round_4,rounddd_4, on=['User_ID','Departure','Arrival'], how="inner")
round__4
# Out:
#     User_ID           Departure       Arrival Departure_Date Return_Date  \
# 0        34              Khowai       Ayodhya     2020-05-07  2020-07-12
# 1        34              Bhopal        Mysuru     2021-04-15  2021-05-22
# 2        63  Thiruvananthapuram    Vijayawada     2019-07-23  2019-11-07
# 3        63              Nashik    Coimbatore     2020-02-13  2020-03-18
# 4       132            Dehradun     Bengaluru     2019-10-10  2019-10-20
# ..      ...                 ...           ...            ...         ...
# 65     1080            Amritsar          Kota     2020-03-05  2020-05-23
# 66     1104           Delhi NCR      Guwahati     2020-04-30  2020-05-07
# 67     1104          Jamshedpur      Amritsar     2020-12-24  2021-01-02
# 68     1165         Bhubaneswar  Kullu-Manali     2019-10-31  2019-11-03
# 69     1165              Indore          Kota     2020-12-31  2021-01-02
#
#     Roundtrip_Cost  travelCode  flightType Flight_agency Departure_date  \
# ...

# %%
round__4 = round__4.drop(columns={'Departure_date','Calculated_Flight_Price','Return Date','Total Flights'})

# %%
round__4
# Out:
#     User_ID           Departure       Arrival Departure_Date Return_Date  \
# 0        34              Khowai       Ayodhya     2020-05-07  2020-07-12
# 1        34              Bhopal        Mysuru     2021-04-15  2021-05-22
# 2        63  Thiruvananthapuram    Vijayawada     2019-07-23  2019-11-07
# 3        63              Nashik    Coimbatore     2020-02-13  2020-03-18
# 4       132            Dehradun     Bengaluru     2019-10-10  2019-10-20
# ..      ...                 ...           ...            ...         ...
# 65     1080            Amritsar          Kota     2020-03-05  2020-05-23
# 66     1104           Delhi NCR      Guwahati     2020-04-30  2020-05-07
# 67     1104          Jamshedpur      Amritsar     2020-12-24  2021-01-02
# 68     1165         Bhubaneswar  Kullu-Manali     2019-10-31  2019-11-03
# 69     1165              Indore          Kota     2020-12-31  2021-01-02
#
#     Roundtrip_Cost  travelCode  flightType Flight_agency  \
# ...

# %%
reorder = ['travelCode','User_ID','Departure','Arrival','Departure_Date','Return_Date','flightType','Flight_agency','Flight Distance (km)','Flight Duration (hh:mm)','Departure Time','Arrival Time','Roundtrip_Cost']

# %%
round__4 = round__4[reorder]

# %%
round__4
# Out:
#     travelCode  User_ID           Departure       Arrival Departure_Date  \
# 0         3442       34              Khowai       Ayodhya     2020-05-07
# 1         3498       34              Bhopal        Mysuru     2021-04-15
# 2         6385       63  Thiruvananthapuram    Vijayawada     2019-07-23
# 3         6502       63              Nashik    Coimbatore     2020-02-13
# 4        13400      132            Dehradun     Bengaluru     2019-10-10
# ..         ...      ...                 ...           ...            ...
# 65      109044     1080            Amritsar          Kota     2020-03-05
# 66      111460     1104           Delhi NCR      Guwahati     2020-04-30
# 67      111482     1104          Jamshedpur      Amritsar     2020-12-24
# 68      117598     1165         Bhubaneswar  Kullu-Manali     2019-10-31
# 69      117742     1165              Indore          Kota     2020-12-31
#
#    Return_Date  flightType Flight_agency  Flight Distance (km)  \
# ...

# %%
round_6 = pd.read_excel('roundtrip_detailed_costs_user6.xlsx')
round_6
# Out:
#     User_ID                From             To Departure_Date Return_Date  \
# 0        93            Ludhiana        Dabolim     2019-07-15  2019-11-07
# 1        93            Bilaspur      Hyderabad     2020-01-23  2020-01-30
# 2        93          Puducherry       Guwahati     2020-04-09  2020-09-08
# 3       641           Hyderabad          Surat     2020-08-13  2020-08-18
# 4       641         Navi Mumbai        Dabolim     2021-05-19  2021-08-05
# 5       641              Nashik          Surat     2021-04-08  2021-08-19
# 6       737                Puri     Coimbatore     2019-10-10  2019-10-24
# 7       737              Mumbai         Jaipur     2020-11-19  2020-11-26
# 8       737                Puri     Puducherry     2020-03-12  2020-12-17
# 9      1039             Raigarh  Visakhapatnam     2021-04-29  2021-05-09
# 10     1039            Amritsar      Delhi NCR     2022-04-14  2022-04-19
# 11     1039              Ranchi       Bilaspur     2022-02-17         NaT
# ...

# %%
round_6['Return_Date'].fillna(pd.to_datetime('2022-02-25'), inplace=True)

# %%
round_6
# Out:
#     User_ID                From             To Departure_Date Return_Date  \
# 0        93            Ludhiana        Dabolim     2019-07-15  2019-11-07
# 1        93            Bilaspur      Hyderabad     2020-01-23  2020-01-30
# 2        93          Puducherry       Guwahati     2020-04-09  2020-09-08
# 3       641           Hyderabad          Surat     2020-08-13  2020-08-18
# 4       641         Navi Mumbai        Dabolim     2021-05-19  2021-08-05
# 5       641              Nashik          Surat     2021-04-08  2021-08-19
# 6       737                Puri     Coimbatore     2019-10-10  2019-10-24
# 7       737              Mumbai         Jaipur     2020-11-19  2020-11-26
# 8       737                Puri     Puducherry     2020-03-12  2020-12-17
# 9      1039             Raigarh  Visakhapatnam     2021-04-29  2021-05-09
# 10     1039            Amritsar      Delhi NCR     2022-04-14  2022-04-19
# 11     1039              Ranchi       Bilaspur     2022-02-17  2022-02-25
# ...

# %%
round_6 = round_6.rename(columns={'From':'Departure','To':'Arrival'})

# %%
r6 = pd.read_excel("dataset_user_6.xlsx")

# %%
r6
# Out:
#     travelCode  User_ID  flightType  Flight_agency       Departure_date  \
# 0         9126       93    economic      Akasa Air           11/07/2019
# 1         9137       93     premium         IndiGo           23/01/2020
# 2         9148       93    economic      Akasa Air           04/09/2020
# 3         9175       93    economic         IndiGo  2019-07-15 00:00:00
# 4         9218       93  firstClass  AirAsia India  2020-09-08 00:00:00
# 5         9231       93    economic      Akasa Air  2020-01-30 00:00:00
# 6        65993      641  firstClass      Akasa Air           13/08/2020
# 7        66020      641  firstClass  AirAsia India  2020-08-18 00:00:00
# 8        66027      641  firstClass      Akasa Air           04/08/2021
# 9        66044      641    economic      Akasa Air           08/05/2021
# 10       66046      641    economic      Akasa Air  2021-08-19 00:00:00
# 11       66048      641    economic      Air India  2021-05-19 00:00:00
# ...

# %%
round_6 = pd.merge(r6,round_6, on=['User_ID','Departure','Arrival'], how="inner")
round_6
# Out:
#     travelCode  User_ID  flightType  Flight_agency       Departure_date  \
# 0         9126       93    economic      Akasa Air           11/07/2019
# 1         9218       93  firstClass  AirAsia India  2020-09-08 00:00:00
# 2         9231       93    economic      Akasa Air  2020-01-30 00:00:00
# 3        66020      641  firstClass  AirAsia India  2020-08-18 00:00:00
# 4        66044      641    economic      Akasa Air           08/05/2021
# 5        66046      641    economic      Akasa Air  2021-08-19 00:00:00
# 6        75625      737  firstClass      Air India           24/10/2019
# 7        75724      737  firstClass          GoAir  2020-11-26 00:00:00
# 8        75750      737     premium         IndiGo  2020-12-17 00:00:00
# 9       104726     1039    economic      Akasa Air  2021-05-09 00:00:00
# 10      104731     1039  firstClass       SpiceJet           31/02/2022
# 11      104753     1039    economic         IndiGo  2022-04-19 00:00:00
# ...

# %%
round_6 = round_6[reorder]
round_6
# Out:
#     travelCode  User_ID           Departure        Arrival Departure_Date  \
# 0         9126       93            Ludhiana        Dabolim     2019-07-15
# 1         9218       93          Puducherry       Guwahati     2020-04-09
# 2         9231       93            Bilaspur      Hyderabad     2020-01-23
# 3        66020      641           Hyderabad          Surat     2020-08-13
# 4        66044      641         Navi Mumbai        Dabolim     2021-05-19
# 5        66046      641              Nashik          Surat     2021-04-08
# 6        75625      737                Puri     Coimbatore     2019-10-10
# 7        75724      737              Mumbai         Jaipur     2020-11-19
# 8        75750      737                Puri     Puducherry     2020-03-12
# 9       104726     1039             Raigarh  Visakhapatnam     2021-04-29
# 10      104731     1039              Ranchi       Bilaspur     2022-02-17
# 11      104753     1039            Amritsar      Delhi NCR     2022-04-14
# ...

# %%
round_3 = pd.read_excel("users_3_occurrences.xlsx")
round_3
# Out:
#    travelCode  User_ID  flightType  Flight_agency       Departure_date  \
# 0       46192      450  firstClass          GoAir           13/02/2020
# 1       46247      450  firstClass      Air India  2020-02-26 00:00:00
# 2       46309      450    economic      Air India           05/12/2022
# 3       96876      958  firstClass  AirAsia India           04/09/2020
# 4       96954      958     premium         IndiGo  2020-09-10 00:00:00
# 5       96982      958    economic      Akasa Air           21/04/2022
# 6      111856     1108     premium      Akasa Air           14/05/2020
# 7      111935     1108     premium         IndiGo           18/11/2021
# 8      111957     1108  firstClass  AirAsia India  2021-11-28 00:00:00
#
#     Departure     Arrival  Flight Distance (km) Flight Duration (hh:mm)  \
# 0  Puducherry    Varanasi               1525.15                   01:41
# 1    Varanasi  Puducherry               1525.15                   01:41
# ...

# %%
round_3 = round_3.dropna(subset=['Return_Date'])
round_3
# Out:
#    travelCode  User_ID  flightType  Flight_agency Departure_date   Departure  \
# 0       46192      450  firstClass          GoAir     13/02/2020  Puducherry
# 2       46309      450    economic      Air India     05/12/2022  Puducherry
# 3       96876      958  firstClass  AirAsia India     04/09/2020        Mopa
# 5       96982      958    economic      Akasa Air     21/04/2022    Amritsar
# 6      111856     1108     premium      Akasa Air     14/05/2020       Hisar
# 7      111935     1108     premium         IndiGo     18/11/2021       Hisar
#
#     Arrival  Flight Distance (km) Flight Duration (hh:mm) Departure Time  \
# 0  Varanasi               1525.15                   01:41          02:00
# 2  Varanasi               1525.15                   01:41          10:29
# 3  Amritsar               7551.25                   08:23          00:31
# 5      Mopa               7551.25                   08:23          06:25
# ...

# %%
round_3 = round_3.rename(columns={'Departure_date':'Departure_Date','Calculated_Flight_Price':'Roundtrip_Cost'})

# %%
round_3 = round_3[reorder]
round_3
# Out:
#    travelCode  User_ID   Departure   Arrival Departure_Date Return_Date  \
# 0       46192      450  Puducherry  Varanasi     13/02/2020  2020-02-26
# 2       46309      450  Puducherry  Varanasi     05/12/2022  2022-12-08
# 3       96876      958        Mopa  Amritsar     04/09/2020  2020-09-10
# 5       96982      958    Amritsar      Mopa     21/04/2022  2022-04-28
# 6      111856     1108       Hisar  Shillong     14/05/2020  2020-05-22
# 7      111935     1108       Hisar  Shillong     18/11/2021  2021-11-28
#
#    flightType  Flight_agency  Flight Distance (km) Flight Duration (hh:mm)  \
# 0  firstClass          GoAir               1525.15                   01:41
# 2    economic      Air India               1525.15                   01:41
# 3  firstClass  AirAsia India               7551.25                   08:23
# 5    economic      Akasa Air               7551.25                   08:23
# 6     premium      Akasa Air               6610.02                   07:20
# ...

# %%
round_2
# Out:
#      travelCode  User_ID  flightType Flight_agency Departure_date   Departure  \
# 0           503        4  firstClass     Air India     2021-03-25    Itanagar
# 2          1479       13    economic        IndiGo     2020-09-07   Bengaluru
# 4          1666       15  firstClass     Air India     2019-11-28  Chandigarh
# 6          2069       18     premium     Akasa Air     2021-01-28        Kota
# 8          2383       21    economic        IndiGo     2021-06-17    Shillong
# ..          ...      ...         ...           ...            ...         ...
# 378      132731     1307  firstClass      SpiceJet     2020-05-21      Ranchi
# 380      133011     1311    economic     Air India     2020-07-30     Gwalior
# 382      133492     1315    economic     Akasa Air     2021-06-05      Shimla
# 384      134586     1323     premium     Air India     2021-12-16   Hyderabad
# 386      135670     1335  firstClass        IndiGo     2019-11-28     Raigarh
#
# ...

# %%
round_2 = round_2.rename(columns={'Departure_date':'Departure_Date','Return Date':'Return_Date','Total Flight Cost':'Roundtrip_Cost'})
round_2 = round_2[reorder]

# %%
Final_RoundTripp = pd.concat([round_2, round_3, round__4, round_6], ignore_index=True)

# %%
round_6.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18 entries, 0 to 17
# Data columns (total 13 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   travelCode               18 non-null     int64
#  1   User_ID                  18 non-null     int64
#  2   Departure                18 non-null     object
#  3   Arrival                  18 non-null     object
#  4   Departure_Date           18 non-null     datetime64[ns]
#  5   Return_Date              18 non-null     datetime64[ns]
#  6   flightType               18 non-null     object
#  7   Flight_agency            18 non-null     object
#  8   Flight Distance (km)     18 non-null     float64
#  9   Flight Duration (hh:mm)  18 non-null     object
#  10  Departure Time           18 non-null     object
#  11  Arrival Time             18 non-null     object
#  12  Roundtrip_Cost           18 non-null     float64
# ...

# %%
Final_RoundTripp.to_excel('Final_RoundTripp.xlsx', index=False)
from IPython.display import FileLink
FileLink('Final_RoundTripp.xlsx')
# Out:
# C:\Users\SURAJ\Desktop\Dataset\notebooks\Final_RoundTripp.xlsx

# %%
update = pd.read_excel('Final_RoundTrip_Buffered.xlsx')
update
# Out:
#      travelCode  User_ID           Departure        Arrival  \
# 0           503        4            Itanagar          Surat
# 1          1479       13           Bengaluru  Visakhapatnam
# 2          1666       15          Chandigarh    Navi Mumbai
# 3          2069       18                Kota  Visakhapatnam
# 4          2383       21            Shillong            Diu
# ..          ...      ...                 ...            ...
# 283      105129     1041  Thiruvananthapuram       Guwahati
# 284      105134     1041              Mysuru        Chennai
# 285      130685     1286            Srinagar           Mopa
# 286      130696     1286          Puducherry        Chennai
# 287      130775     1286          Jamshedpur         Shimla
#
#           Departure_Date Return_Date  flightType Flight_agency  \
# 0    2021-03-25 00:00:00  2021-04-02  firstClass     Air India
# 1    2020-09-07 00:00:00  2020-09-15    economic        IndiGo
# ...

# %%
Final_RoundTrip['Return Departure Time'] = update['Return Departure Time']
Final_RoundTrip
# Out:
#      travelCode  User_ID           Departure        Arrival  \
# 0           503        4            Itanagar          Surat
# 1          1479       13           Bengaluru  Visakhapatnam
# 2          1666       15          Chandigarh    Navi Mumbai
# 3          2069       18                Kota  Visakhapatnam
# 4          2383       21            Shillong            Diu
# ..          ...      ...                 ...            ...
# 283      105129     1041  Thiruvananthapuram       Guwahati
# 284      105134     1041              Mysuru        Chennai
# 285      130685     1286            Srinagar           Mopa
# 286      130696     1286          Puducherry        Chennai
# 287      130775     1286          Jamshedpur         Shimla
#
#           Departure_Date Return_Date  flightType Flight_agency  \
# 0    2021-03-25 00:00:00  2021-04-02  firstClass     Air India
# 1    2020-09-07 00:00:00  2020-09-15    economic        IndiGo
# ...

# %%
Final_RoundTrip['Return Arrival Time'] = update['Return Arrival Time']
Final_RoundTrip
# Out:
#      travelCode  User_ID           Departure        Arrival  \
# 0           503        4            Itanagar          Surat
# 1          1479       13           Bengaluru  Visakhapatnam
# 2          1666       15          Chandigarh    Navi Mumbai
# 3          2069       18                Kota  Visakhapatnam
# 4          2383       21            Shillong            Diu
# ..          ...      ...                 ...            ...
# 283      105129     1041  Thiruvananthapuram       Guwahati
# 284      105134     1041              Mysuru        Chennai
# 285      130685     1286            Srinagar           Mopa
# 286      130696     1286          Puducherry        Chennai
# 287      130775     1286          Jamshedpur         Shimla
#
#           Departure_Date Return_Date  flightType Flight_agency  \
# 0    2021-03-25 00:00:00  2021-04-02  firstClass     Air India
# 1    2020-09-07 00:00:00  2020-09-15    economic        IndiGo
# ...

# %%
Final_RoundTrip.to_excel('Final_Updated_RoundTrip.xlsx', index=False)
from IPython.display import FileLink
FileLink('Final_Updated_RoundTrip.xlsx')
# Out:
# C:\Users\SURAJ\Desktop\Dataset\notebooks\Final_Updated_RoundTrip.xlsx

# %%
round_2
# Out:
#      travelCode  User_ID   Departure        Arrival Departure_Date  \
# 0           503        4    Itanagar          Surat     2021-03-25
# 2          1479       13   Bengaluru  Visakhapatnam     2020-09-07
# 4          1666       15  Chandigarh    Navi Mumbai     2019-11-28
# 6          2069       18        Kota  Visakhapatnam     2021-01-28
# 8          2383       21    Shillong            Diu     2021-06-17
# ..          ...      ...         ...            ...            ...
# 378      132731     1307      Ranchi         Dhubri     2020-05-21
# 380      133011     1311     Gwalior         Nashik     2020-07-30
# 382      133492     1315      Shimla      Delhi NCR     2021-06-05
# 384      134586     1323   Hyderabad       Dehradun     2021-12-16
# 386      135670     1335     Raigarh           Kota     2019-11-28
#
#     Return_Date  flightType Flight_agency  Flight Distance (km)  \
# 0    2021-04-02  firstClass     Air India               2204.62
# ...
