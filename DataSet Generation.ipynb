# %%
import pandas as pd

# %%
flights = pd.read_csv("flights.csv")
flights
# Out:
#         travelCode  userCode                 from                   to  \
# 0                0         0          Recife (PE)   Florianopolis (SC)
# 1                0         0   Florianopolis (SC)          Recife (PE)
# 2                1         0        Brasilia (DF)   Florianopolis (SC)
# 3                1         0   Florianopolis (SC)        Brasilia (DF)
# 4                2         0         Aracaju (SE)        Salvador (BH)
# ...            ...       ...                  ...                  ...
# 271883      135941      1339    Campo Grande (MS)   Florianopolis (SC)
# 271884      135942      1339   Florianopolis (SC)           Natal (RN)
# 271885      135942      1339           Natal (RN)   Florianopolis (SC)
# 271886      135943      1339   Florianopolis (SC)  Rio de Janeiro (RJ)
# 271887      135943      1339  Rio de Janeiro (RJ)   Florianopolis (SC)
#
#         flightType    price  time  distance       agency        date
# ...

# %%
df_filtered = flights.iloc[0::2]
df_filtered
# Out:
#         travelCode  userCode                from                   to  \
# 0                0         0         Recife (PE)   Florianopolis (SC)
# 2                1         0       Brasilia (DF)   Florianopolis (SC)
# 4                2         0        Aracaju (SE)        Salvador (BH)
# 6                3         0        Aracaju (SE)    Campo Grande (MS)
# 8                4         0         Recife (PE)   Florianopolis (SC)
# ...            ...       ...                 ...                  ...
# 271878      135939      1339  Florianopolis (SC)        Brasilia (DF)
# 271880      135940      1339  Florianopolis (SC)    Campo Grande (MS)
# 271882      135941      1339  Florianopolis (SC)    Campo Grande (MS)
# 271884      135942      1339  Florianopolis (SC)           Natal (RN)
# 271886      135943      1339  Florianopolis (SC)  Rio de Janeiro (RJ)
#
#         flightType    price  time  distance       agency        date
# ...

# %%
hotels = pd.read_csv("hotels.csv")
hotels
# Out:
#        travelCode  userCode      name               place  days   price  \
# 0               0         0   Hotel A  Florianopolis (SC)     4  313.02
# 1               2         0   Hotel K       Salvador (BH)     2  263.41
# 2               7         0   Hotel K       Salvador (BH)     3  263.41
# 3              11         0   Hotel K       Salvador (BH)     4  263.41
# 4              13         0   Hotel A  Florianopolis (SC)     1  313.02
# ...           ...       ...       ...                 ...   ...     ...
# 40547      135938      1339  Hotel BP       Brasilia (DF)     3  247.62
# 40548      135939      1339  Hotel BP       Brasilia (DF)     1  247.62
# 40549      135940      1339  Hotel BW   Campo Grande (MS)     3   60.39
# 40550      135941      1339  Hotel BW   Campo Grande (MS)     3   60.39
# 40551      135942      1339  Hotel BD          Natal (RN)     4  242.88
#
#          total        date
# 0      1252.08  09/26/2019
# 1       526.82  10/10/2019
# ...

# %%
users = pd.read_csv("users.csv")
users
# Out:
#       code        company              name  gender  age
# 0        0           4You         Roy Braun    male   21
# 1        1           4You    Joseph Holsten    male   37
# 2        2           4You     Wilma Mcinnis  female   48
# 3        3           4You      Paula Daniel  female   23
# 4        4           4You   Patricia Carson  female   44
# ...    ...            ...               ...     ...  ...
# 1335  1335  Umbrella LTDA  Albert Garroutte    male   23
# 1336  1336  Umbrella LTDA        Kim Shores  female   40
# 1337  1337  Umbrella LTDA     James Gimenez    male   28
# 1338  1338  Umbrella LTDA      Viola Agosta  female   52
# 1339  1339  Umbrella LTDA    Paul Rodriguez    male   35
#
# [1340 rows x 5 columns]

# %%
users = users.rename(columns={'code': 'userCode'})

# %%
merged_df = pd.merge(df_filtered, hotels, on= 'travelCode', how='inner')
merged_df
# Out:
#        travelCode  userCode_x                from                  to  \
# 0               0           0         Recife (PE)  Florianopolis (SC)
# 1               2           0        Aracaju (SE)       Salvador (BH)
# 2               7           0        Aracaju (SE)       Salvador (BH)
# 3              11           0       Brasilia (DF)       Salvador (BH)
# 4              13           0         Recife (PE)  Florianopolis (SC)
# ...           ...         ...                 ...                 ...
# 40547      135938        1339  Florianopolis (SC)       Brasilia (DF)
# 40548      135939        1339  Florianopolis (SC)       Brasilia (DF)
# 40549      135940        1339  Florianopolis (SC)   Campo Grande (MS)
# 40550      135941        1339  Florianopolis (SC)   Campo Grande (MS)
# 40551      135942        1339  Florianopolis (SC)          Natal (RN)
#
#        flightType  price_x  time  distance       agency      date_x  \
# ...

# %%
users = users.rename(columns={'userCode': 'userCode_x'})
User_merged = pd.merge(users, merged_df, on= 'userCode_x', how='right')

# %%
User_merged
# Out:
#        userCode_x        company          name_x gender  age  travelCode  \
# 0               0           4You       Roy Braun   male   21           0
# 1               0           4You       Roy Braun   male   21           2
# 2               0           4You       Roy Braun   male   21           7
# 3               0           4You       Roy Braun   male   21          11
# 4               0           4You       Roy Braun   male   21          13
# ...           ...            ...             ...    ...  ...         ...
# 40547        1339  Umbrella LTDA  Paul Rodriguez   male   35      135938
# 40548        1339  Umbrella LTDA  Paul Rodriguez   male   35      135939
# 40549        1339  Umbrella LTDA  Paul Rodriguez   male   35      135940
# 40550        1339  Umbrella LTDA  Paul Rodriguez   male   35      135941
# 40551        1339  Umbrella LTDA  Paul Rodriguez   male   35      135942
#
#                      from                  to  flightType  price_x  ...  \
# ...

# %%
User_merged_df = pd.merge(users, merged_df, on= 'userCode_x', how='inner')
User_merged_df
# Out:
#        userCode_x        company          name_x gender  age  travelCode  \
# 0               0           4You       Roy Braun   male   21           0
# 1               0           4You       Roy Braun   male   21           2
# 2               0           4You       Roy Braun   male   21           7
# 3               0           4You       Roy Braun   male   21          11
# 4               0           4You       Roy Braun   male   21          13
# ...           ...            ...             ...    ...  ...         ...
# 40547        1339  Umbrella LTDA  Paul Rodriguez   male   35      135938
# 40548        1339  Umbrella LTDA  Paul Rodriguez   male   35      135939
# 40549        1339  Umbrella LTDA  Paul Rodriguez   male   35      135940
# 40550        1339  Umbrella LTDA  Paul Rodriguez   male   35      135941
# 40551        1339  Umbrella LTDA  Paul Rodriguez   male   35      135942
#
#                      from                  to  flightType  price_x  ...  \
# ...

# %%
rent_car = pd.read_csv("rent_a_car.csv")
ren_car = rent_car.drop(['pickupDateTime','dropoffDateTime'],axis=1)

# %%
ren_car.rename(columns = {'code':'userCode_x'})
# Out:
#       travelCode  userCode_x     pickupLocation   dropoffLocation    carType  \
# 0         126191         195         Aliciabury         Lopezbury      Sedan
# 1          18474        1086     Edwardsborough      North Daniel        SUV
# 2          90427          90    West Danielside        Riverafort      Sedan
# 3         123934          75     North Samantha      North Joseph     Luxury
# 4          98809         300           Cobbview       Amandaburgh     Luxury
# ...          ...         ...                ...               ...        ...
# 9995         407         558  North Destinybury        West Tyler        SUV
# 9996      114887        1256        Williamside        New Ashley      Sedan
# 9997       40666         280     North Alexbury       Mortonville      Sedan
# 9998      115752         424          Clarkfurt  East Christopher  Hatchback
# 9999       39934        1318     Blackwellshire      Nicholasfurt     Luxury
#
# ...

# %%
len(pd.unique(ren_car['pickupLocation']))
# Out:
# 7670

# %%
len(pd.unique(ren_car['dropoffLocation']))
# Out:
# 7672

# %%
pd.value_counts(ren_car['rentalDuration'])
# Out:
# rentalDuration
# 4    2025
# 5    2016
# 1    1996
# 3    1995
# 2    1968
# Name: count, dtype: int64

# %%
pd.value_counts(ren_car['dropoffLocation'])
# Out:
# dropoffLocation
# South Michael       13
# Lake Michael        13
# North James         11
# East Christopher    10
# East David          10
#                     ..
# Wilkinsborough       1
# Millerberg           1
# Monicashire          1
# Alexanderburgh       1
# Nicholasfurt         1
# Name: count, Length: 7672, dtype: int64

# %%
import random

arr_drop_loc = pd.unique(ren_car['dropoffLocation'])
arr_pick_loc = pd.unique(ren_car['pickupLocation'])
arr_car_type = pd.unique(ren_car['carType'])
arr_car_rental_agency = pd.unique(ren_car['rentalAgency'])
arr_car_rental_duration = pd.unique(ren_car['rentalDuration'])
arr_fuelPolicy_car = pd.unique(ren_car['fuelPolicy'])
arr_bookingStatus_car = pd.unique(ren_car['bookingStatus'])
arr_Car_totalDistance = pd.unique(ren_car['totalDistance'])
# random_value_droploc = random.choice(arr)  # Select one random value
# print(random_value_droploc)

# %%
import numpy as np

np.random.seed(42)  

User_merged_df['dropoffLocation_car'] = np.random.choice(arr_drop_loc, size=len(User_merged_df))
User_merged_df['pickupLocation_car'] = np.random.choice(arr_pick_loc, size=len(User_merged_df))
User_merged_df['car_Type'] = np.random.choice(arr_car_type, size=len(User_merged_df))
User_merged_df['Car_rentalAgency'] = np.random.choice(arr_car_rental_agency, size=len(User_merged_df))
User_merged_df['Car_rentalDuration'] = np.random.choice(arr_car_rental_duration, size=len(User_merged_df))
User_merged_df['Car_fuelPolicy'] = np.random.choice(arr_fuelPolicy_car, size=len(User_merged_df))
User_merged_df['Car_totalDistance'] = np.random.choice(arr_Car_totalDistance , size=len(User_merged_df))
# User_merged_df['pickupLocation_car'] = np.random.choice(arr_pick_loc, size=len(User_merged_df))

# %%
User_merged_df['Car_bookingStatus'] = np.random.choice(arr_bookingStatus_car, size=len(User_merged_df))

# %%
User_merged_df
# pd.value_counts(User_merged_df['Car_rentalDuration'])
# Out:
#        userCode_x        company          name_x gender  age  travelCode  \
# 0               0           4You       Roy Braun   male   21           0
# 1               0           4You       Roy Braun   male   21           2
# 2               0           4You       Roy Braun   male   21           7
# 3               0           4You       Roy Braun   male   21          11
# 4               0           4You       Roy Braun   male   21          13
# ...           ...            ...             ...    ...  ...         ...
# 40547        1339  Umbrella LTDA  Paul Rodriguez   male   35      135938
# 40548        1339  Umbrella LTDA  Paul Rodriguez   male   35      135939
# 40549        1339  Umbrella LTDA  Paul Rodriguez   male   35      135940
# 40550        1339  Umbrella LTDA  Paul Rodriguez   male   35      135941
# 40551        1339  Umbrella LTDA  Paul Rodriguez   male   35      135942
#
#                      from                  to  flightType  price_x  ...  \
# ...

# %%
ren_car['price'].mean()
# Out:
# 347.276828

# %%
base_fare = 100
rate_per_hour = 50
rate_per_km = 10
User_merged_df['car_rent_price'] = (
    base_fare +
    (User_merged_df['Car_rentalDuration'] * rate_per_hour) +
    (User_merged_df['Car_totalDistance'] * rate_per_km) +
    np.random.randint(10, 51, size=len(User_merged_df))  
    )

# %%
User_merged_df
# Out:
#        userCode_x        company          name_x gender  age  travelCode  \
# 0               0           4You       Roy Braun   male   21           0
# 1               0           4You       Roy Braun   male   21           2
# 2               0           4You       Roy Braun   male   21           7
# 3               0           4You       Roy Braun   male   21          11
# 4               0           4You       Roy Braun   male   21          13
# ...           ...            ...             ...    ...  ...         ...
# 40547        1339  Umbrella LTDA  Paul Rodriguez   male   35      135938
# 40548        1339  Umbrella LTDA  Paul Rodriguez   male   35      135939
# 40549        1339  Umbrella LTDA  Paul Rodriguez   male   35      135940
# 40550        1339  Umbrella LTDA  Paul Rodriguez   male   35      135941
# 40551        1339  Umbrella LTDA  Paul Rodriguez   male   35      135942
#
#                      from                  to  flightType  price_x  ...  \
# ...

# %%
User_merged_df.to_excel('dataset.xlsx', index=False)

# %%
from IPython.display import FileLink
FileLink('dataset.xlsx')
# Out:
# C:\Users\SURAJ\Desktop\Dataset\dataset.xlsx

# %%
ren_car
# Out:
#       travelCode  code     pickupLocation   dropoffLocation    carType  \
# 0         126191   195         Aliciabury         Lopezbury      Sedan
# 1          18474  1086     Edwardsborough      North Daniel        SUV
# 2          90427    90    West Danielside        Riverafort      Sedan
# 3         123934    75     North Samantha      North Joseph     Luxury
# 4          98809   300           Cobbview       Amandaburgh     Luxury
# ...          ...   ...                ...               ...        ...
# 9995         407   558  North Destinybury        West Tyler        SUV
# 9996      114887  1256        Williamside        New Ashley      Sedan
# 9997       40666   280     North Alexbury       Mortonville      Sedan
# 9998      115752   424          Clarkfurt  East Christopher  Hatchback
# 9999       39934  1318     Blackwellshire      Nicholasfurt     Luxury
#
#      rentalAgency  rentalDuration   price  totalDistance    fuelPolicy  \
# ...

# %%
final_df = pd.merge(User_merged,ren_car, on='travelCode', how='left')

# %%
final_df
# Out:
#        userCode_x        company          name_x gender  age  travelCode  \
# 0               0           4You       Roy Braun   male   21           0
# 1               0           4You       Roy Braun   male   21           2
# 2               0           4You       Roy Braun   male   21           7
# 3               0           4You       Roy Braun   male   21          11
# 4               0           4You       Roy Braun   male   21          13
# ...           ...            ...             ...    ...  ...         ...
# 40733        1339  Umbrella LTDA  Paul Rodriguez   male   35      135938
# 40734        1339  Umbrella LTDA  Paul Rodriguez   male   35      135939
# 40735        1339  Umbrella LTDA  Paul Rodriguez   male   35      135940
# 40736        1339  Umbrella LTDA  Paul Rodriguez   male   35      135941
# 40737        1339  Umbrella LTDA  Paul Rodriguez   male   35      135942
#
#                      from                  to  flightType  price_x  ...  \
# ...

# %%
final_df.drop('price', axis=1)
# Out:
#        userCode_x        company          name_x gender  age  travelCode  \
# 0               0           4You       Roy Braun   male   21           0
# 1               0           4You       Roy Braun   male   21           2
# 2               0           4You       Roy Braun   male   21           7
# 3               0           4You       Roy Braun   male   21          11
# 4               0           4You       Roy Braun   male   21          13
# ...           ...            ...             ...    ...  ...         ...
# 40733        1339  Umbrella LTDA  Paul Rodriguez   male   35      135938
# 40734        1339  Umbrella LTDA  Paul Rodriguez   male   35      135939
# 40735        1339  Umbrella LTDA  Paul Rodriguez   male   35      135940
# 40736        1339  Umbrella LTDA  Paul Rodriguez   male   35      135941
# 40737        1339  Umbrella LTDA  Paul Rodriguez   male   35      135942
#
#                      from                  to  flightType  price_x  ...  \
# ...

# %%
final_df.to_excel('datasett.xlsx', index=False)
FileLink('datasett.xlsx')
# Out:
# C:\Users\SURAJ\Desktop\Dataset\datasett.xlsx

# %%
final_df = final_df.rename(columns={'userCode_x':'User_Id', 'name_x':'Name', 'from':'Departure', 'to':'Arrival', 'price_x':'Flight_price', 'time':'Flight_duration', 'distance':'Flight_Distance', 'agency':'Flight_agency', 'date_x':'Departure_date', 'place':'Arrival_place', 'days':'Hotel_stay'})
final_df.columns
# Out:
# Index(['User_Id', 'company', 'Name', 'gender', 'age', 'travelCode',
#        'Departure', 'Arrival', 'flightType', 'Flight_price', 'Flight_duration',
#        'Flight_Distance', 'Flight_agency', 'Departure_date', 'userCode_y',
#        'name_y', 'Arrival_place', 'Hotel_stay', 'price_y', 'total', 'date_y',
#        'code', 'pickupLocation', 'dropoffLocation', 'carType', 'rentalAgency',
#        'rentalDuration', 'price', 'totalDistance', 'fuelPolicy',
#        'bookingStatus'],
#       dtype='object')

# %%
final_df = final_df.rename(columns={'name_y':'Hotel_Name', 'price_y':'Hotel_per_day_price', 'total':'Hotel_TotalPrice', 'date_y':'Check-in','price':'Car_price','totalDistance':'Car_Distance','bookingStatus':'Car_bookingStatus'})
final_df.to_excel('Fdatasett.xlsx', index=False)
FileLink('Fdatasett.xlsx')
# Out:
# C:\Users\SURAJ\Desktop\Dataset\Fdatasett.xlsx

# %%
# final_df = final_df.drop(['userCode_y', 'code', 'Car_price'], axis=1)
final_df.to_excel('Finaldatasett.xlsx', index=False)
FileLink('Finaldatasett.xlsx')
# Out:
# C:\Users\SURAJ\Desktop\Dataset\Finaldatasett.xlsx

# %%
final_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40738 entries, 0 to 40737
# Data columns (total 31 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   User_Id              40738 non-null  int64
#  1   company              40738 non-null  object
#  2   Name                 40738 non-null  object
#  3   gender               40738 non-null  object
#  4   age                  40738 non-null  int64
#  5   travelCode           40738 non-null  int64
#  6   Departure            40738 non-null  object
#  7   Arrival              40738 non-null  object
#  8   flightType           40738 non-null  object
#  9   Flight_price         40738 non-null  float64
#  10  Flight_duration      40738 non-null  float64
#  11  Flight_Distance      40738 non-null  float64
#  12  Flight_agency        40738 non-null  object
#  13  Departure_date       40738 non-null  object
#  14  userCode_y           40738 non-null  int64
# ...

# %%
final_df['carType'].fillna('Not Rented', inplace=True)
# final_df['carType'].unique()
final_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40738 entries, 0 to 40737
# Data columns (total 31 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   User_Id              40738 non-null  int64
#  1   company              40738 non-null  object
#  2   Name                 40738 non-null  object
#  3   gender               40738 non-null  object
#  4   age                  40738 non-null  int64
#  5   travelCode           40738 non-null  int64
#  6   Departure            40738 non-null  object
#  7   Arrival              40738 non-null  object
#  8   flightType           40738 non-null  object
#  9   Flight_price         40738 non-null  float64
#  10  Flight_duration      40738 non-null  float64
#  11  Flight_Distance      40738 non-null  float64
#  12  Flight_agency        40738 non-null  object
#  13  Departure_date       40738 non-null  object
#  14  userCode_y           40738 non-null  int64
# ...

# %%
pricing = {
    'Not Rented': {'base_fare': 0, 'rate_per_hour': 0, 'rate_per_km': 0},
    'Hatchback': {'base_fare': 200, 'rate_per_hour': 50, 'rate_per_km': 8},
    'Sedan': {'base_fare': 300, 'rate_per_hour': 70, 'rate_per_km': 10},
    'SUV': {'base_fare': 400, 'rate_per_hour': 90, 'rate_per_km': 12},
    'Luxury': {'base_fare': 800, 'rate_per_hour': 150, 'rate_per_km': 20},
}

# %%
# import numpy as np

# %%
final_df
# Out:
#        User_Id        company            Name gender  age  travelCode  \
# 0            0           4You       Roy Braun   male   21           0
# 1            0           4You       Roy Braun   male   21           2
# 2            0           4You       Roy Braun   male   21           7
# 3            0           4You       Roy Braun   male   21          11
# 4            0           4You       Roy Braun   male   21          13
# ...        ...            ...             ...    ...  ...         ...
# 40733     1339  Umbrella LTDA  Paul Rodriguez   male   35      135938
# 40734     1339  Umbrella LTDA  Paul Rodriguez   male   35      135939
# 40735     1339  Umbrella LTDA  Paul Rodriguez   male   35      135940
# 40736     1339  Umbrella LTDA  Paul Rodriguez   male   35      135941
# 40737     1339  Umbrella LTDA  Paul Rodriguez   male   35      135942
#
#                 Departure             Arrival  flightType  Flight_price  ...  \
# ...

# %%
ren_car
# Out:
#       travelCode  code     pickupLocation   dropoffLocation    carType  \
# 0         126191   195         Aliciabury         Lopezbury      Sedan
# 1          18474  1086     Edwardsborough      North Daniel        SUV
# 2          90427    90    West Danielside        Riverafort      Sedan
# 3         123934    75     North Samantha      North Joseph     Luxury
# 4          98809   300           Cobbview       Amandaburgh     Luxury
# ...          ...   ...                ...               ...        ...
# 9995         407   558  North Destinybury        West Tyler        SUV
# 9996      114887  1256        Williamside        New Ashley      Sedan
# 9997       40666   280     North Alexbury       Mortonville      Sedan
# 9998      115752   424          Clarkfurt  East Christopher  Hatchback
# 9999       39934  1318     Blackwellshire      Nicholasfurt     Luxury
#
#      rentalAgency  rentalDuration   price  totalDistance    fuelPolicy  \
# ...

# %%
# ren_car = ren_car.drop(['code','price'], axis=1)
ren_car = ren_car.rename(columns={'totalDistance':'Car_total_distance'})
ren_car
# Out:
#       travelCode  code     pickupLocation   dropoffLocation    carType  \
# 0         126191   195         Aliciabury         Lopezbury      Sedan
# 1          18474  1086     Edwardsborough      North Daniel        SUV
# 2          90427    90    West Danielside        Riverafort      Sedan
# 3         123934    75     North Samantha      North Joseph     Luxury
# 4          98809   300           Cobbview       Amandaburgh     Luxury
# ...          ...   ...                ...               ...        ...
# 9995         407   558  North Destinybury        West Tyler        SUV
# 9996      114887  1256        Williamside        New Ashley      Sedan
# 9997       40666   280     North Alexbury       Mortonville      Sedan
# 9998      115752   424          Clarkfurt  East Christopher  Hatchback
# 9999       39934  1318     Blackwellshire      Nicholasfurt     Luxury
#
#      rentalAgency  rentalDuration   price  Car_total_distance    fuelPolicy  \
# ...

# %%
def calculate_rent(row):
    car = row['carType']
    
    # Handle cases where carType is not in pricing dictionary
    if car not in pricing or pd.isna(car) or car == 'Not Rented':
        return 0.0  # No charge for Not Rented cars
    
    base_fare = pricing[car]['base_fare']
    rate_per_hour = pricing[car]['rate_per_hour']
    rate_per_km = pricing[car]['rate_per_km']

    # Handle NaN values by replacing with 0
    rental_duration = row['rentalDuration'] if not pd.isna(row['rentalDuration']) else 0
    distance = row['Car_total_distance'] if not pd.isna(row['Car_total_distance']) else 0

    # Calculate total price
    total_price = (
        base_fare +
        (rental_duration * rate_per_hour) +
        (distance * rate_per_km) +
        np.random.randint(10, 51)  # Random charge between 10 and 50
    )
    
    return total_price

# Apply function
ren_car['total_rent_price'] = ren_car.apply(calculate_rent, axis=1)

# %%
ren_car
# Out:
#       travelCode  code     pickupLocation   dropoffLocation    carType  \
# 0         126191   195         Aliciabury         Lopezbury      Sedan
# 1          18474  1086     Edwardsborough      North Daniel        SUV
# 2          90427    90    West Danielside        Riverafort      Sedan
# 3         123934    75     North Samantha      North Joseph     Luxury
# 4          98809   300           Cobbview       Amandaburgh     Luxury
# ...          ...   ...                ...               ...        ...
# 9995         407   558  North Destinybury        West Tyler        SUV
# 9996      114887  1256        Williamside        New Ashley      Sedan
# 9997       40666   280     North Alexbury       Mortonville      Sedan
# 9998      115752   424          Clarkfurt  East Christopher  Hatchback
# 9999       39934  1318     Blackwellshire      Nicholasfurt     Luxury
#
#      rentalAgency  rentalDuration   price  Car_total_distance    fuelPolicy  \
# ...

# %%
Final_DF = pd.merge(User_merged, ren_car, on="travelCode", how="left")
Final_DF['total_rent_price'] = Final_DF['total_rent_price'].fillna(0)  # Keeps it as a number

# %%
Final_DF.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40738 entries, 0 to 40737
# Data columns (total 32 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   userCode_x          40738 non-null  int64
#  1   company             40738 non-null  object
#  2   name_x              40738 non-null  object
#  3   gender              40738 non-null  object
#  4   age                 40738 non-null  int64
#  5   travelCode          40738 non-null  int64
#  6   from                40738 non-null  object
#  7   to                  40738 non-null  object
#  8   flightType          40738 non-null  object
#  9   price_x             40738 non-null  float64
#  10  time                40738 non-null  float64
#  11  distance            40738 non-null  float64
#  12  agency              40738 non-null  object
#  13  date_x              40738 non-null  object
#  14  userCode_y          40738 non-null  int64
# ...

# %%
Final_DF = Final_DF.rename(columns={'userCode_x':'User_Id', 'name_x':'Name', 'from':'Departure', 'to':'Arrival', 'price_x':'Flight_price', 'time':'Flight_duration', 'distance':'Flight_Distance', 'agency':'Flight_agency', 'date_x':'Departure_date', 'place':'Arrival_place', 'days':'Hotel_stay','name_y':'Hotel_Name', 'price_y':'Hotel_per_day_price', 'total':'Hotel_TotalPrice', 'date_y':'Check-in','price':'Car_price','totalDistance':'Car_Distance','bookingStatus':'Car_bookingStatus'})

# %%
Final_DF.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40738 entries, 0 to 40737
# Data columns (total 32 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   User_Id              40738 non-null  int64
#  1   company              40738 non-null  object
#  2   Name                 40738 non-null  object
#  3   gender               40738 non-null  object
#  4   age                  40738 non-null  int64
#  5   travelCode           40738 non-null  int64
#  6   Departure            40738 non-null  object
#  7   Arrival              40738 non-null  object
#  8   flightType           40738 non-null  object
#  9   Flight_price         40738 non-null  float64
#  10  Flight_duration      40738 non-null  float64
#  11  Flight_Distance      40738 non-null  float64
#  12  Flight_agency        40738 non-null  object
#  13  Departure_date       40738 non-null  object
#  14  userCode_y           40738 non-null  int64
# ...

# %%
Final_DF.drop(['code','userCode_y'],axis=1,inplace=True)
Final_DF.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40738 entries, 0 to 40737
# Data columns (total 30 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   User_Id              40738 non-null  int64
#  1   company              40738 non-null  object
#  2   Name                 40738 non-null  object
#  3   gender               40738 non-null  object
#  4   age                  40738 non-null  int64
#  5   travelCode           40738 non-null  int64
#  6   Departure            40738 non-null  object
#  7   Arrival              40738 non-null  object
#  8   flightType           40738 non-null  object
#  9   Flight_price         40738 non-null  float64
#  10  Flight_duration      40738 non-null  float64
#  11  Flight_Distance      40738 non-null  float64
#  12  Flight_agency        40738 non-null  object
#  13  Departure_date       40738 non-null  object
#  14  Hotel_Name           40738 non-null  object
# ...

# %%
Final_DF['total_trip_cost'] = Final_DF[['Flight_price', 'Hotel_TotalPrice', 'total_rent_price']].sum(axis=1,skipna=True)

# %%
Final_DF.to_excel('FINALdatasett.xlsx', index=False)
FileLink('FINALdatasett.xlsx')
# Out:
# C:\Users\SURAJ\Desktop\Dataset\FINALdatasett.xlsx

# %%
Final_DF.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40738 entries, 0 to 40737
# Data columns (total 31 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   User_Id              40738 non-null  int64
#  1   company              40738 non-null  object
#  2   Name                 40738 non-null  object
#  3   gender               40738 non-null  object
#  4   age                  40738 non-null  int64
#  5   travelCode           40738 non-null  int64
#  6   Departure            40738 non-null  object
#  7   Arrival              40738 non-null  object
#  8   flightType           40738 non-null  object
#  9   Flight_price         40738 non-null  float64
#  10  Flight_duration      40738 non-null  float64
#  11  Flight_Distance      40738 non-null  float64
#  12  Flight_agency        40738 non-null  object
#  13  Departure_date       40738 non-null  object
#  14  Hotel_Name           40738 non-null  object
# ...

# %% [markdown]
# Final_DF.to_excel('FINALdatasett.xlsx', index=False)
# FileLink('FINALdatasett.xlsx')

# %% [markdown]
# Final_DF.to_csv("FinalllData.csv", index = False)

# %%
Final_DF.columns
# Out:
# Index(['User_Id', 'company', 'Name', 'gender', 'age', 'travelCode',
#        'Departure', 'Arrival', 'flightType', 'Flight_price', 'Flight_duration',
#        'Flight_Distance', 'Flight_agency', 'Departure_date', 'Hotel_Name',
#        'Arrival_place', 'Hotel_stay', 'Hotel_per_day_price',
#        'Hotel_TotalPrice', 'Check-in', 'pickupLocation', 'dropoffLocation',
#        'carType', 'rentalAgency', 'rentalDuration', 'Car_price',
#        'Car_total_distance', 'fuelPolicy', 'Car_bookingStatus',
#        'total_rent_price', 'total_trip_cost'],
#       dtype='object')

# %%
Final_DF.drop('total_trip_cost',axis=1, inplace=True)
Final_DF.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40738 entries, 0 to 40737
# Data columns (total 30 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   User_Id              40738 non-null  int64
#  1   company              40738 non-null  object
#  2   Name                 40738 non-null  object
#  3   gender               40738 non-null  object
#  4   age                  40738 non-null  int64
#  5   travelCode           40738 non-null  int64
#  6   Departure            40738 non-null  object
#  7   Arrival              40738 non-null  object
#  8   flightType           40738 non-null  object
#  9   Flight_price         40738 non-null  float64
#  10  Flight_duration      40738 non-null  float64
#  11  Flight_Distance      40738 non-null  float64
#  12  Flight_agency        40738 non-null  object
#  13  Departure_date       40738 non-null  object
#  14  Hotel_Name           40738 non-null  object
# ...
